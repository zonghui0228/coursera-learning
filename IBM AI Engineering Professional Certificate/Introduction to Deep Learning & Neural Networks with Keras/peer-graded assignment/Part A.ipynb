# %% [markdown]
# # Importing two libraries Pandas and Numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing Data through assests

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_7f7eb230e07e402c99532a6852470126 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='TDy0q2o8LZCaKrbA0Kx--GY9m6nP-pt-WZXBmVCUJScA',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_7f7eb230e07e402c99532a6852470126.get_object(Bucket='regressionmodelinkeras-donotdelete-pr-639txrgp1rb3un',Key='concrete_data.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

concrete_data = pd.read_csv(body)
concrete_data.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a76d9bd56c0c> in <module>
#       2 import pandas as pd
#       3 from botocore.client import Config
# ----> 4 import ibm_boto3
#       5
#       6 def __iter__(self): return 0
#
# ModuleNotFoundError: No module named 'ibm_boto3'

# %% [markdown]
# Let's check how many data points we have.

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# # Split data into predictors and target

# %%
concrete_data_columns = concrete_data.columns

X = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
Y = concrete_data['Strength'] # Strength column
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %% [markdown]
# checking for predictors values

# %%
X_train.head()
# Out:
#      Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 900   150.0               237.0      0.0  174.0              12.0
# 370   218.9                 0.0    124.1  158.5              11.3
# 604   339.0                 0.0      0.0  197.0               0.0
# 973   143.8               136.3    106.2  178.1               7.5
# 593   252.5                 0.0      0.0  185.7               0.0
#
#      Coarse Aggregate  Fine Aggregate  Age
# 900            1069.0           675.0   28
# 370            1078.7           794.9   14
# 604             968.0           781.0  365
# 973             941.5           774.3   28
# 593            1111.6           784.3    7

# %% [markdown]
# Now Checking for target values

# %%
y_train.head()
# Out:
# 900    37.43
# 370    26.05
# 604    38.89
# 973    26.15
# 593    11.48
# Name: Strength, dtype: float64

# %%
n_cols = X_train.shape[1] # number of predictors

# %% [markdown]
# # Let's go ahead and import the Keras library

# %%
import keras

# %% [markdown]
# Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# # Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# build the model
model = regression_model()

mean_error = []
for i in range(0,50):
    

    # Next, we will train and test the model at the same time using the fit method. We will leave out 30% of
    # the data for validation and we will train the model for 50 epochs.
    # fit the model
    model.fit(X_train, y_train, validation_split=0, epochs=50, verbose=2)

    y_pred = model.predict(X_test)

    from sklearn.metrics import mean_squared_error
    mean_error.append(mean_squared_error(y_pred, y_test))
    i=i+1
print(i)
# Out:
# Epoch 1/50
#  - 1s - loss: 2939.5232
# Epoch 2/50
#  - 0s - loss: 509.0104
# Epoch 3/50
#  - 0s - loss: 320.8377
# Epoch 4/50
#  - 0s - loss: 255.3379
# Epoch 5/50
#  - 0s - loss: 206.6966
# Epoch 6/50
#  - 0s - loss: 181.8333
# Epoch 7/50
#  - 0s - loss: 156.9936
# Epoch 8/50
#  - 1s - loss: 160.7450
# Epoch 9/50
#  - 0s - loss: 128.9731
# Epoch 10/50
#  - 0s - loss: 118.6501
# Epoch 11/50
#  - 0s - loss: 111.4625
# Epoch 12/50
#  - 0s - loss: 101.9604
# Epoch 13/50
#  - 0s - loss: 96.9501
# Epoch 14/50
#  - 0s - loss: 92.4678
# Epoch 15/50
#  - 1s - loss: 83.9002
# Epoch 16/50
#  - 0s - loss: 75.9506
# Epoch 17/50
#  - 1s - loss: 76.8316
# Epoch 18/50
#  - 0s - loss: 71.0616
# Epoch 19/50
#  - 0s - loss: 74.1462
# Epoch 20/50
#  - 0s - loss: 71.7753
# Epoch 21/50
#  - 0s - loss: 67.7069
# Epoch 22/50
#  - 0s - loss: 64.8942
# Epoch 23/50
#  - 0s - loss: 63.4531
# Epoch 24/50
#  - 0s - loss: 58.0602
# Epoch 25/50
#  - 0s - loss: 57.5847
# Epoch 26/50
#  - 0s - loss: 74.3644
# Epoch 27/50
#  - 0s - loss: 68.9319
# Epoch 28/50
#  - 0s - loss: 59.8715
# Epoch 29/50
#  - 0s - loss: 65.7692
# Epoch 30/50
#  - 0s - loss: 64.8589
# Epoch 31/50
#  - 0s - loss: 59.7435
# Epoch 32/50
#  - 0s - loss: 60.0643
# Epoch 33/50
#  - 0s - loss: 59.9155
# Epoch 34/50
#  - 0s - loss: 59.6647
# Epoch 35/50
#  - 0s - loss: 72.6053
# Epoch 36/50
#  - 0s - loss: 61.8029
# Epoch 37/50
#  - 0s - loss: 51.4329
# Epoch 38/50
#  - 0s - loss: 56.6685
# Epoch 39/50
#  - 0s - loss: 52.2024
# Epoch 40/50
#  - 0s - loss: 50.5656
# Epoch 41/50
#  - 0s - loss: 60.4468
# Epoch 42/50
#  - 0s - loss: 53.2341
# Epoch 43/50
#  - 0s - loss: 52.8557
# Epoch 44/50
#  - 0s - loss: 49.5351
# Epoch 45/50
#  - 0s - loss: 57.2919
# Epoch 46/50
#  - 0s - loss: 60.2863
# Epoch 47/50
#  - 0s - loss: 66.9840
# Epoch 48/50
#  - 0s - loss: 49.7433
# Epoch 49/50
#  - 0s - loss: 45.4166
# Epoch 50/50
#  - 0s - loss: 49.1531
# Epoch 1/50
#  - 0s - loss: 52.9437
# Epoch 2/50
#  - 0s - loss: 46.6507
# Epoch 3/50
#  - 0s - loss: 43.8232
# Epoch 4/50
#  - 0s - loss: 45.7724
# Epoch 5/50
#  - 0s - loss: 44.5343
# Epoch 6/50
#  - 0s - loss: 45.2181
# Epoch 7/50
#  - 0s - loss: 45.0409
# Epoch 8/50
#  - 0s - loss: 44.1375
# Epoch 9/50
#  - 0s - loss: 51.0155
# Epoch 10/50
#  - 0s - loss: 42.6541
# Epoch 11/50
#  - 0s - loss: 51.7723
# Epoch 12/50
#  - 0s - loss: 46.4528
# Epoch 13/50
#  - 0s - loss: 47.1846
# Epoch 14/50
#  - 0s - loss: 51.1445
# Epoch 15/50
#  - 0s - loss: 44.1275
# Epoch 16/50
#  - 0s - loss: 44.6065
# Epoch 17/50
#  - 0s - loss: 44.9956
# Epoch 18/50
#  - 0s - loss: 47.3976
# Epoch 19/50
#  - 0s - loss: 43.6784
# Epoch 20/50
#  - 0s - loss: 44.1636
# Epoch 21/50
#  - 0s - loss: 42.0973
# Epoch 22/50
#  - 2s - loss: 45.9503
# Epoch 23/50
#  - 0s - loss: 44.6965
# Epoch 24/50
#  - 0s - loss: 43.3666
# Epoch 25/50
#  - 0s - loss: 40.3387
# Epoch 26/50
#  - 0s - loss: 44.2112
# Epoch 27/50
#  - 0s - loss: 50.2159
# Epoch 28/50
#  - 0s - loss: 50.3389
# Epoch 29/50
#  - 0s - loss: 42.5353
# Epoch 30/50
#  - 0s - loss: 44.4314
# Epoch 31/50
#  - 0s - loss: 46.4018
# Epoch 32/50
#  - 0s - loss: 48.1566
# Epoch 33/50
#  - 1s - loss: 47.8396
# Epoch 34/50
#  - 0s - loss: 48.6345
# Epoch 35/50
#  - 0s - loss: 47.1809
# Epoch 36/50
#  - 0s - loss: 38.5875
# Epoch 37/50
#  - 0s - loss: 39.9492
# Epoch 38/50
#  - 0s - loss: 39.2676
# Epoch 39/50
#  - 0s - loss: 41.8198
# Epoch 40/50
#  - 0s - loss: 44.3042
# Epoch 41/50
#  - 0s - loss: 49.4015
# Epoch 42/50
#  - 0s - loss: 51.2193
# Epoch 43/50
#  - 0s - loss: 43.0016
# Epoch 44/50
#  - 0s - loss: 41.7680
# Epoch 45/50
#  - 0s - loss: 44.9822
# Epoch 46/50
#  - 0s - loss: 41.3707
# Epoch 47/50
#  - 0s - loss: 39.7836
# Epoch 48/50
#  - 0s - loss: 37.4145
# Epoch 49/50
#  - 0s - loss: 42.4391
# Epoch 50/50
#  - 0s - loss: 55.9126
# Epoch 1/50
#  - 0s - loss: 40.4073
# Epoch 2/50
#  - 0s - loss: 43.4261
# Epoch 3/50
#  - 0s - loss: 43.0286
# Epoch 4/50
#  - 0s - loss: 40.0396
# Epoch 5/50
#  - 0s - loss: 40.9553
# Epoch 6/50
#  - 0s - loss: 44.7446
# Epoch 7/50
#  - 0s - loss: 40.4150
# Epoch 8/50
#  - 0s - loss: 44.2360
# Epoch 9/50
#  - 0s - loss: 42.3737
# Epoch 10/50
#  - 0s - loss: 38.2233
# Epoch 11/50
#  - 0s - loss: 40.0497
# Epoch 12/50
#  - 0s - loss: 40.5388
# Epoch 13/50
#  - 0s - loss: 52.0074
# Epoch 14/50
#  - 0s - loss: 41.5080
# Epoch 15/50
#  - 0s - loss: 54.7643
# Epoch 16/50
#  - 0s - loss: 50.4087
# Epoch 17/50
#  - 0s - loss: 43.4539
# Epoch 18/50
#  - 0s - loss: 46.4066
# Epoch 19/50
#  - 0s - loss: 44.3201
# Epoch 20/50
#  - 0s - loss: 45.1816
# Epoch 21/50
#  - 0s - loss: 42.3241
# Epoch 22/50
#  - 1s - loss: 40.1258
# Epoch 23/50
#  - 0s - loss: 39.4056
# Epoch 24/50
#  - 0s - loss: 44.7021
# Epoch 25/50
#  - 1s - loss: 39.1836
# Epoch 26/50
#  - 0s - loss: 39.8768
# Epoch 27/50
#  - 0s - loss: 40.8522
# Epoch 28/50
#  - 0s - loss: 37.1395
# Epoch 29/50
#  - 0s - loss: 38.9746
# Epoch 30/50
#  - 0s - loss: 62.5287
# Epoch 31/50
#  - 0s - loss: 49.8650
# Epoch 32/50
#  - 0s - loss: 37.6658
# Epoch 33/50
#  - 0s - loss: 38.9100
# Epoch 34/50
#  - 0s - loss: 40.4448
# Epoch 35/50
#  - 0s - loss: 46.0481
# Epoch 36/50
#  - 0s - loss: 39.8691
# Epoch 37/50
#  - 0s - loss: 37.4144
# Epoch 38/50
#  - 0s - loss: 44.3182
# Epoch 39/50
#  - 0s - loss: 38.8702
# Epoch 40/50
#  - 0s - loss: 39.2571
# Epoch 41/50
#  - 0s - loss: 42.2384
# Epoch 42/50
#  - 0s - loss: 40.6229
# Epoch 43/50
#  - 0s - loss: 38.4485
# Epoch 44/50
#  - 0s - loss: 42.3383
# Epoch 45/50
#  - 0s - loss: 38.9896
# Epoch 46/50
#  - 0s - loss: 58.3773
# Epoch 47/50
#  - 0s - loss: 47.6282
# Epoch 48/50
#  - 0s - loss: 56.9951
# Epoch 49/50
#  - 0s - loss: 42.2756
# Epoch 50/50
#  - 0s - loss: 41.8271
# Epoch 1/50
#  - 0s - loss: 43.5509
# Epoch 2/50
#  - 0s - loss: 37.4624
# Epoch 3/50
#  - 0s - loss: 43.1073
# Epoch 4/50
#  - 0s - loss: 39.1292
# Epoch 5/50
#  - 0s - loss: 39.2498
# Epoch 6/50
#  - 0s - loss: 43.6605
# Epoch 7/50
#  - 0s - loss: 38.0741
# Epoch 8/50
#  - 0s - loss: 44.5783
# Epoch 9/50
#  - 0s - loss: 35.4310
# Epoch 10/50
#  - 0s - loss: 39.7428
# Epoch 11/50
#  - 0s - loss: 45.2699
# Epoch 12/50
#  - 0s - loss: 46.0962
# Epoch 13/50
#  - 0s - loss: 43.8447
# Epoch 14/50
#  - 0s - loss: 37.4824
# Epoch 15/50
#  - 1s - loss: 37.0953
# Epoch 16/50
#  - 0s - loss: 36.1421
# Epoch 17/50
#  - 0s - loss: 35.7263
# Epoch 18/50
#  - 0s - loss: 42.7827
# Epoch 19/50
#  - 0s - loss: 35.6845
# Epoch 20/50
#  - 0s - loss: 42.5483
# Epoch 21/50
#  - 0s - loss: 38.6005
# Epoch 22/50
#  - 0s - loss: 51.6987
# Epoch 23/50
#  - 0s - loss: 51.1375
# Epoch 24/50
#  - 0s - loss: 36.0523
# Epoch 25/50
#  - 1s - loss: 46.2292
# Epoch 26/50
#  - 0s - loss: 43.0237
# Epoch 27/50
#  - 0s - loss: 36.0717
# Epoch 28/50
#  - 1s - loss: 41.2843
# Epoch 29/50
#  - 0s - loss: 34.2463
# Epoch 30/50
#  - 0s - loss: 33.7188
# Epoch 31/50
#  - 0s - loss: 37.1444
# Epoch 32/50
#  - 0s - loss: 39.1239
# Epoch 33/50
#  - 0s - loss: 43.4038
# Epoch 34/50
#  - 0s - loss: 33.6736
# Epoch 35/50
#  - 0s - loss: 39.2041
# Epoch 36/50
#  - 0s - loss: 36.4114
# Epoch 37/50
#  - 0s - loss: 63.5751
# Epoch 38/50
#  - 0s - loss: 40.9955
# Epoch 39/50
#  - 0s - loss: 46.0749
# Epoch 40/50
#  - 0s - loss: 34.5742
# Epoch 41/50
#  - 0s - loss: 39.6317
# Epoch 42/50
#  - 0s - loss: 38.0512
# Epoch 43/50
#  - 0s - loss: 38.9508
# Epoch 44/50
#  - 0s - loss: 47.8274
# Epoch 45/50
#  - 0s - loss: 39.5795
# Epoch 46/50
#  - 0s - loss: 41.8395
# Epoch 47/50
#  - 0s - loss: 37.7873
# Epoch 48/50
#  - 0s - loss: 42.7200
# Epoch 49/50
#  - 0s - loss: 35.8169
# Epoch 50/50
#  - 0s - loss: 34.6850
# Epoch 1/50
#  - 0s - loss: 33.7933
# Epoch 2/50
#  - 0s - loss: 32.2010
# Epoch 3/50
#  - 0s - loss: 32.7598
# Epoch 4/50
#  - 0s - loss: 35.9301
# Epoch 5/50
#  - 0s - loss: 38.4267
# Epoch 6/50
#  - 0s - loss: 32.7857
# Epoch 7/50
#  - 0s - loss: 57.2053
# Epoch 8/50
#  - 0s - loss: 46.8406
# Epoch 9/50
#  - 0s - loss: 43.4451
# Epoch 10/50
#  - 0s - loss: 38.2890
# Epoch 11/50
#  - 0s - loss: 35.6079
# Epoch 12/50
#  - 0s - loss: 39.3144
# Epoch 13/50
#  - 0s - loss: 40.9599
# Epoch 14/50
#  - 0s - loss: 32.9501
# Epoch 15/50
#  - 0s - loss: 33.2583
# Epoch 16/50
#  - 0s - loss: 38.8650
# Epoch 17/50
#  - 0s - loss: 58.4272
# Epoch 18/50
#  - 0s - loss: 45.0776
# Epoch 19/50
#  - 0s - loss: 34.1937
# Epoch 20/50
#  - 0s - loss: 30.6326
# Epoch 21/50
#  - 0s - loss: 35.1651
# Epoch 22/50
#  - 0s - loss: 40.1824
# Epoch 23/50
#  - 0s - loss: 32.1391
# Epoch 24/50
#  - 0s - loss: 39.3327
# Epoch 25/50
#  - 0s - loss: 39.5671
# Epoch 26/50
#  - 0s - loss: 32.1318
# Epoch 27/50
#  - 0s - loss: 38.6758
# Epoch 28/50
#  - 0s - loss: 40.5830
# Epoch 29/50
#  - 0s - loss: 33.3806
# Epoch 30/50
#  - 0s - loss: 38.3010
# Epoch 31/50
#  - 0s - loss: 35.8723
# Epoch 32/50
#  - 1s - loss: 31.3601
# Epoch 33/50
#  - 1s - loss: 44.3161
# Epoch 34/50
#  - 0s - loss: 31.7493
# Epoch 35/50
#  - 0s - loss: 39.8937
# Epoch 36/50
#  - 0s - loss: 36.4840
# Epoch 37/50
#  - 0s - loss: 37.6727
# Epoch 38/50
#  - 0s - loss: 34.5937
# Epoch 39/50
#  - 0s - loss: 32.9753
# Epoch 40/50
#  - 0s - loss: 32.0224
# Epoch 41/50
#  - 0s - loss: 33.7956
# Epoch 42/50
#  - 0s - loss: 36.9591
# Epoch 43/50
#  - 0s - loss: 31.1950
# Epoch 44/50
#  - 0s - loss: 34.2439
# Epoch 45/50
#  - 0s - loss: 30.9236
# Epoch 46/50
#  - 0s - loss: 34.1585
# Epoch 47/50
#  - 0s - loss: 32.9675
# Epoch 48/50
#  - 0s - loss: 34.9730
# Epoch 49/50
#  - 0s - loss: 42.9084
# Epoch 50/50
#  - 0s - loss: 39.6789
# Epoch 1/50
#  - 0s - loss: 30.9723
# Epoch 2/50
#  - 0s - loss: 34.5091
# Epoch 3/50
#  - 0s - loss: 33.4257
# Epoch 4/50
#  - 0s - loss: 31.6678
# Epoch 5/50
#  - 0s - loss: 31.6826
# Epoch 6/50
#  - 0s - loss: 31.4016
# Epoch 7/50
#  - 0s - loss: 41.0561
# Epoch 8/50
#  - 0s - loss: 32.8626
# Epoch 9/50
#  - 0s - loss: 29.8725
# Epoch 10/50
#  - 0s - loss: 31.9409
# Epoch 11/50
#  - 0s - loss: 32.6289
# Epoch 12/50
#  - 0s - loss: 40.4551
# Epoch 13/50
#  - 0s - loss: 29.3480
# Epoch 14/50
#  - 0s - loss: 37.2642
# Epoch 15/50
#  - 0s - loss: 37.5085
# Epoch 16/50
#  - 0s - loss: 31.6256
# Epoch 17/50
#  - 0s - loss: 29.9037
# Epoch 18/50
#  - 0s - loss: 35.0166
# Epoch 19/50
#  - 0s - loss: 29.2300
# Epoch 20/50
#  - 0s - loss: 39.7545
# Epoch 21/50
#  - 0s - loss: 30.5109
# Epoch 22/50
#  - 0s - loss: 32.3577
# Epoch 23/50
#  - 0s - loss: 37.6157
# Epoch 24/50
#  - 0s - loss: 29.6910
# Epoch 25/50
#  - 0s - loss: 33.5282
# Epoch 26/50
#  - 0s - loss: 36.5788
# Epoch 27/50
#  - 0s - loss: 41.1083
# Epoch 28/50
#  - 0s - loss: 29.1330
# Epoch 29/50
#  - 0s - loss: 32.5074
# Epoch 30/50
#  - 0s - loss: 28.9149
# Epoch 31/50
#  - 0s - loss: 38.7086
# Epoch 32/50
#  - 0s - loss: 35.1713
# Epoch 33/50
#  - 0s - loss: 32.0428
# Epoch 34/50
#  - 0s - loss: 33.6626
# Epoch 35/50
#  - 0s - loss: 30.2825
# Epoch 36/50
#  - 3s - loss: 28.1248
# Epoch 37/50
#  - 0s - loss: 36.6454
# Epoch 38/50
#  - 0s - loss: 50.3585
# Epoch 39/50
#  - 0s - loss: 29.7427
# Epoch 40/50
#  - 0s - loss: 32.9633
# Epoch 41/50
#  - 0s - loss: 36.2129
# Epoch 42/50
#  - 0s - loss: 36.0912
# Epoch 43/50
#  - 0s - loss: 37.0715
# Epoch 44/50
#  - 0s - loss: 39.1054
# Epoch 45/50
#  - 0s - loss: 34.3590
# Epoch 46/50
#  - 0s - loss: 34.0910
# Epoch 47/50
#  - 0s - loss: 41.3223
# Epoch 48/50
#  - 0s - loss: 35.9294
# Epoch 49/50
#  - 0s - loss: 28.7356
# Epoch 50/50
#  - 0s - loss: 28.1818
# Epoch 1/50
#  - 0s - loss: 29.2841
# Epoch 2/50
#  - 0s - loss: 28.7948
# Epoch 3/50
#  - 0s - loss: 31.8479
# Epoch 4/50
#  - 0s - loss: 31.1573
# Epoch 5/50
#  - 0s - loss: 27.3047
# Epoch 6/50
#  - 0s - loss: 26.5828
# Epoch 7/50
#  - 0s - loss: 28.4338
# Epoch 8/50
#  - 0s - loss: 42.7960
# Epoch 9/50
#  - 0s - loss: 33.1424
# Epoch 10/50
#  - 0s - loss: 28.0978
# Epoch 11/50
#  - 0s - loss: 26.6199
# Epoch 12/50
#  - 0s - loss: 28.2948
# Epoch 13/50
#  - 0s - loss: 27.8273
# Epoch 14/50
#  - 0s - loss: 30.5146
# Epoch 15/50
#  - 0s - loss: 34.6553
# Epoch 16/50
#  - 0s - loss: 32.9600
# Epoch 17/50
#  - 0s - loss: 29.9862
# Epoch 18/50
#  - 0s - loss: 27.5721
# Epoch 19/50
#  - 0s - loss: 36.8942
# Epoch 20/50
#  - 0s - loss: 32.3423
# Epoch 21/50
#  - 0s - loss: 28.4465
# Epoch 22/50
#  - 0s - loss: 36.2405
# Epoch 23/50
#  - 0s - loss: 46.6072
# Epoch 24/50
#  - 0s - loss: 30.3746
# Epoch 25/50
#  - 0s - loss: 28.0606
# Epoch 26/50
#  - 0s - loss: 25.8614
# Epoch 27/50
#  - 0s - loss: 30.9670
# Epoch 28/50
#  - 0s - loss: 38.1104
# Epoch 29/50
#  - 0s - loss: 29.2052
# Epoch 30/50
#  - 0s - loss: 31.6859
# Epoch 31/50
#  - 0s - loss: 25.6075
# Epoch 32/50
#  - 0s - loss: 27.4065
# Epoch 33/50
#  - 0s - loss: 30.5533
# Epoch 34/50
#  - 0s - loss: 30.5219
# Epoch 35/50
#  - 0s - loss: 46.4784
# Epoch 36/50
#  - 0s - loss: 39.2612
# Epoch 37/50
#  - 0s - loss: 30.5826
# Epoch 38/50
#  - 0s - loss: 29.5725
# Epoch 39/50
#  - 0s - loss: 28.7953
# Epoch 40/50
#  - 0s - loss: 27.5485
# Epoch 41/50
#  - 3s - loss: 30.0569
# Epoch 42/50
#  - 0s - loss: 28.6580
# Epoch 43/50
#  - 0s - loss: 29.6206
# Epoch 44/50
#  - 0s - loss: 27.7374
# Epoch 45/50
#  - 0s - loss: 30.1733
# Epoch 46/50
#  - 0s - loss: 35.4074
# Epoch 47/50
#  - 0s - loss: 28.0959
# Epoch 48/50
#  - 0s - loss: 29.1208
# Epoch 49/50
#  - 0s - loss: 26.2126
# Epoch 50/50
#  - 0s - loss: 28.8763
# Epoch 1/50
#  - 0s - loss: 27.8803
# Epoch 2/50
#  - 0s - loss: 25.5341
# Epoch 3/50
#  - 0s - loss: 26.8106
# Epoch 4/50
#  - 0s - loss: 25.4482
# Epoch 5/50
#  - 0s - loss: 33.3276
# Epoch 6/50
#  - 0s - loss: 34.8535
# Epoch 7/50
#  - 0s - loss: 27.0283
# Epoch 8/50
#  - 0s - loss: 31.4720
# Epoch 9/50
#  - 0s - loss: 31.5759
# Epoch 10/50
#  - 0s - loss: 28.0691
# Epoch 11/50
#  - 0s - loss: 33.3651
# Epoch 12/50
#  - 0s - loss: 35.2814
# Epoch 13/50
#  - 0s - loss: 27.3338
# Epoch 14/50
#  - 0s - loss: 30.9174
# Epoch 15/50
#  - 0s - loss: 34.6987
# Epoch 16/50
#  - 0s - loss: 24.7712
# Epoch 17/50
#  - 0s - loss: 29.8991
# Epoch 18/50
#  - 0s - loss: 24.8687
# Epoch 19/50
#  - 0s - loss: 29.2446
# Epoch 20/50
#  - 0s - loss: 26.9495
# Epoch 21/50
#  - 1s - loss: 29.7299
# Epoch 22/50
#  - 0s - loss: 29.7710
# Epoch 23/50
#  - 0s - loss: 26.5512
# Epoch 24/50
#  - 0s - loss: 39.2831
# Epoch 25/50
#  - 0s - loss: 37.4731
# Epoch 26/50
#  - 0s - loss: 31.4830
# Epoch 27/50
#  - 0s - loss: 26.9996
# Epoch 28/50
#  - 0s - loss: 28.3780
# Epoch 29/50
#  - 0s - loss: 33.2033
# Epoch 30/50
#  - 0s - loss: 27.8372
# Epoch 31/50
#  - 0s - loss: 26.8625
# Epoch 32/50
#  - 0s - loss: 32.0243
# Epoch 33/50
#  - 0s - loss: 32.4490
# Epoch 34/50
#  - 0s - loss: 33.7869
# Epoch 35/50
#  - 0s - loss: 28.7304
# Epoch 36/50
#  - 0s - loss: 28.3839
# Epoch 37/50
#  - 0s - loss: 28.8755
# Epoch 38/50
#  - 0s - loss: 28.0282
# Epoch 39/50
#  - 1s - loss: 25.9735
# Epoch 40/50
#  - 0s - loss: 25.6207
# Epoch 41/50
#  - 1s - loss: 28.6637
# Epoch 42/50
#  - 0s - loss: 31.7284
# Epoch 43/50
#  - 0s - loss: 30.9790
# Epoch 44/50
#  - 0s - loss: 25.4892
# Epoch 45/50
#  - 0s - loss: 24.4669
# Epoch 46/50
#  - 0s - loss: 27.7067
# Epoch 47/50
#  - 0s - loss: 27.9962
# Epoch 48/50
#  - 0s - loss: 29.2402
# Epoch 49/50
#  - 0s - loss: 26.2253
# Epoch 50/50
#  - 0s - loss: 30.0115
# Epoch 1/50
#  - 0s - loss: 30.4839
# Epoch 2/50
#  - 0s - loss: 31.4774
# Epoch 3/50
#  - 0s - loss: 33.6733
# Epoch 4/50
#  - 0s - loss: 26.0312
# Epoch 5/50
#  - 0s - loss: 35.4366
# Epoch 6/50
#  - 0s - loss: 37.6402
# Epoch 7/50
#  - 0s - loss: 30.2221
# Epoch 8/50
#  - 0s - loss: 25.2521
# Epoch 9/50
#  - 0s - loss: 23.9144
# Epoch 10/50
#  - 0s - loss: 29.9672
# Epoch 11/50
#  - 0s - loss: 25.9524
# Epoch 12/50
#  - 0s - loss: 27.8552
# Epoch 13/50
#  - 0s - loss: 27.2807
# Epoch 14/50
#  - 0s - loss: 25.4286
# Epoch 15/50
#  - 0s - loss: 32.9611
# Epoch 16/50
#  - 0s - loss: 27.0514
# Epoch 17/50
#  - 0s - loss: 30.2259
# Epoch 18/50
#  - 0s - loss: 26.7589
# Epoch 19/50
#  - 0s - loss: 28.8479
# Epoch 20/50
#  - 0s - loss: 26.8233
# Epoch 21/50
#  - 0s - loss: 36.6453
# Epoch 22/50
#  - 0s - loss: 29.1847
# Epoch 23/50
#  - 0s - loss: 26.6719
# Epoch 24/50
#  - 0s - loss: 24.2228
# Epoch 25/50
#  - 0s - loss: 28.2381
# Epoch 26/50
#  - 0s - loss: 27.4810
# Epoch 27/50
#  - 0s - loss: 25.4805
# Epoch 28/50
#  - 0s - loss: 25.9857
# Epoch 29/50
#  - 0s - loss: 28.1178
# Epoch 30/50
#  - 0s - loss: 27.4986
# Epoch 31/50
#  - 0s - loss: 25.0331
# Epoch 32/50
#  - 0s - loss: 25.6383
# Epoch 33/50
#  - 0s - loss: 27.9331
# Epoch 34/50
#  - 0s - loss: 27.6634
# Epoch 35/50
#  - 0s - loss: 27.6069
# Epoch 36/50
#  - 0s - loss: 24.4237
# Epoch 37/50
#  - 0s - loss: 26.2176
# Epoch 38/50
#  - 0s - loss: 24.8450
# Epoch 39/50
#  - 0s - loss: 25.7635
# Epoch 40/50
#  - 0s - loss: 33.3713
# Epoch 41/50
#  - 1s - loss: 34.5609
# Epoch 42/50
#  - 1s - loss: 33.4548
# Epoch 43/50
#  - 0s - loss: 24.7085
# Epoch 44/50
#  - 1s - loss: 24.2856
# Epoch 45/50
#  - 0s - loss: 24.5636
# Epoch 46/50
#  - 0s - loss: 26.6226
# Epoch 47/50
#  - 0s - loss: 29.9506
# Epoch 48/50
#  - 0s - loss: 30.2011
# Epoch 49/50
#  - 0s - loss: 33.2840
# Epoch 50/50
#  - 0s - loss: 24.3643
# Epoch 1/50
#  - 0s - loss: 27.5484
# Epoch 2/50
#  - 0s - loss: 30.9296
# Epoch 3/50
#  - 0s - loss: 28.8146
# Epoch 4/50
#  - 0s - loss: 29.1940
# Epoch 5/50
#  - 0s - loss: 23.2728
# Epoch 6/50
#  - 0s - loss: 25.2275
# Epoch 7/50
#  - 0s - loss: 28.7677
# Epoch 8/50
#  - 0s - loss: 27.1127
# Epoch 9/50
#  - 0s - loss: 36.2394
# Epoch 10/50
#  - 0s - loss: 36.2304
# Epoch 11/50
#  - 0s - loss: 29.2630
# Epoch 12/50
#  - 0s - loss: 24.1310
# Epoch 13/50
#  - 0s - loss: 24.6063
# Epoch 14/50
#  - 0s - loss: 31.7282
# Epoch 15/50
#  - 0s - loss: 29.8227
# Epoch 16/50
#  - 0s - loss: 27.0521
# Epoch 17/50
#  - 0s - loss: 25.6460
# Epoch 18/50
#  - 0s - loss: 26.8650
# Epoch 19/50
#  - 0s - loss: 25.9545
# Epoch 20/50
#  - 0s - loss: 26.9647
# Epoch 21/50
#  - 0s - loss: 25.0362
# Epoch 22/50
#  - 0s - loss: 26.6891
# Epoch 23/50
#  - 0s - loss: 24.8417
# Epoch 24/50
#  - 0s - loss: 25.1212
# Epoch 25/50
#  - 0s - loss: 26.8966
# Epoch 26/50
#  - 0s - loss: 26.1018
# Epoch 27/50
#  - 0s - loss: 30.8522
# Epoch 28/50
#  - 0s - loss: 26.1545
# Epoch 29/50
#  - 0s - loss: 25.1141
# Epoch 30/50
#  - 0s - loss: 33.5260
# Epoch 31/50
#  - 0s - loss: 26.5278
# Epoch 32/50
#  - 0s - loss: 27.9232
# Epoch 33/50
#  - 0s - loss: 26.8484
# Epoch 34/50
#  - 0s - loss: 24.6103
# Epoch 35/50
#  - 0s - loss: 25.7457
# Epoch 36/50
#  - 0s - loss: 28.9545
# Epoch 37/50
#  - 0s - loss: 24.6149
# Epoch 38/50
#  - 0s - loss: 25.9325
# Epoch 39/50
#  - 0s - loss: 28.0007
# Epoch 40/50
#  - 0s - loss: 28.3063
# Epoch 41/50
#  - 0s - loss: 27.9910
# Epoch 42/50
#  - 0s - loss: 32.5286
# Epoch 43/50
#  - 0s - loss: 27.5568
# Epoch 44/50
#  - 0s - loss: 26.7009
# Epoch 45/50
#  - 0s - loss: 30.9147
# Epoch 46/50
#  - 2s - loss: 34.9127
# Epoch 47/50
#  - 0s - loss: 26.5873
# Epoch 48/50
#  - 1s - loss: 24.0545
# Epoch 49/50
#  - 0s - loss: 24.1585
# Epoch 50/50
#  - 0s - loss: 28.6390
# Epoch 1/50
#  - 0s - loss: 25.9106
# Epoch 2/50
#  - 0s - loss: 26.6693
# Epoch 3/50
#  - 0s - loss: 22.4451
# Epoch 4/50
#  - 0s - loss: 23.8429
# Epoch 5/50
#  - 0s - loss: 25.6445
# Epoch 6/50
#  - 0s - loss: 34.0504
# Epoch 7/50
#  - 0s - loss: 28.2596
# Epoch 8/50
#  - 0s - loss: 24.6790
# Epoch 9/50
#  - 0s - loss: 26.2500
# Epoch 10/50
#  - 0s - loss: 24.6594
# Epoch 11/50
#  - 0s - loss: 26.0627
# Epoch 12/50
#  - 0s - loss: 29.6710
# Epoch 13/50
#  - 0s - loss: 29.8282
# Epoch 14/50
#  - 0s - loss: 31.5327
# Epoch 15/50
#  - 0s - loss: 26.3550
# Epoch 16/50
#  - 0s - loss: 26.2905
# Epoch 17/50
#  - 0s - loss: 24.2245
# Epoch 18/50
#  - 0s - loss: 28.7265
# Epoch 19/50
#  - 0s - loss: 27.1063
# Epoch 20/50
#  - 0s - loss: 24.3765
# Epoch 21/50
#  - 0s - loss: 28.4101
# Epoch 22/50
#  - 0s - loss: 30.0882
# Epoch 23/50
#  - 0s - loss: 27.9848
# Epoch 24/50
#  - 0s - loss: 26.0368
# Epoch 25/50
#  - 0s - loss: 25.7662
# Epoch 26/50
#  - 0s - loss: 28.6021
# Epoch 27/50
#  - 0s - loss: 25.5622
# Epoch 28/50
#  - 0s - loss: 34.9181
# Epoch 29/50
#  - 0s - loss: 26.8831
# Epoch 30/50
#  - 0s - loss: 25.1770
# Epoch 31/50
#  - 0s - loss: 24.7722
# Epoch 32/50
#  - 0s - loss: 26.8054
# Epoch 33/50
#  - 0s - loss: 27.7769
# Epoch 34/50
#  - 0s - loss: 34.3931
# Epoch 35/50
#  - 0s - loss: 30.1182
# Epoch 36/50
#  - 0s - loss: 27.8538
# Epoch 37/50
#  - 0s - loss: 27.1351
# Epoch 38/50
#  - 0s - loss: 24.9618
# Epoch 39/50
#  - 0s - loss: 23.2133
# Epoch 40/50
#  - 0s - loss: 22.4325
# Epoch 41/50
#  - 0s - loss: 27.5854
# Epoch 42/50
#  - 0s - loss: 28.3644
# Epoch 43/50
#  - 0s - loss: 24.0068
# Epoch 44/50
#  - 0s - loss: 23.1940
# Epoch 45/50
#  - 0s - loss: 36.4755
# Epoch 46/50
#  - 0s - loss: 23.7742
# Epoch 47/50
#  - 0s - loss: 23.0513
# Epoch 48/50
#  - 0s - loss: 23.8300
# Epoch 49/50
#  - 0s - loss: 25.2936
# Epoch 50/50
#  - 0s - loss: 23.9329
# Epoch 1/50
#  - 0s - loss: 24.3185
# Epoch 2/50
#  - 0s - loss: 22.0907
# Epoch 3/50
#  - 1s - loss: 23.8570
# Epoch 4/50
#  - 0s - loss: 24.9131
# Epoch 5/50
#  - 0s - loss: 23.5684
# Epoch 6/50
#  - 1s - loss: 27.8444
# Epoch 7/50
#  - 0s - loss: 24.0273
# Epoch 8/50
#  - 0s - loss: 23.7356
# Epoch 9/50
#  - 0s - loss: 25.4003
# Epoch 10/50
#  - 0s - loss: 23.4186
# Epoch 11/50
#  - 0s - loss: 23.8867
# Epoch 12/50
#  - 0s - loss: 25.4593
# Epoch 13/50
#  - 0s - loss: 23.0928
# Epoch 14/50
#  - 0s - loss: 25.0510
# Epoch 15/50
#  - 0s - loss: 23.3509
# Epoch 16/50
#  - 0s - loss: 30.4202
# Epoch 17/50
#  - 0s - loss: 30.9891
# Epoch 18/50
#  - 0s - loss: 29.7140
# Epoch 19/50
#  - 0s - loss: 29.7759
# Epoch 20/50
#  - 0s - loss: 27.9143
# Epoch 21/50
#  - 0s - loss: 27.8416
# Epoch 22/50
#  - 0s - loss: 25.4966
# Epoch 23/50
#  - 0s - loss: 24.4824
# Epoch 24/50
#  - 0s - loss: 29.3366
# Epoch 25/50
#  - 0s - loss: 22.8790
# Epoch 26/50
#  - 0s - loss: 23.7378
# Epoch 27/50
#  - 0s - loss: 25.1315
# Epoch 28/50
#  - 0s - loss: 24.7367
# Epoch 29/50
#  - 0s - loss: 23.7791
# Epoch 30/50
#  - 0s - loss: 28.8301
# Epoch 31/50
#  - 1s - loss: 26.3770
# Epoch 32/50
#  - 0s - loss: 24.4770
# Epoch 33/50
#  - 0s - loss: 25.6083
# Epoch 34/50
#  - 0s - loss: 26.2688
# Epoch 35/50
#  - 0s - loss: 25.1708
# Epoch 36/50
#  - 0s - loss: 26.6048
# Epoch 37/50
#  - 0s - loss: 26.1523
# Epoch 38/50
#  - 0s - loss: 24.4292
# Epoch 39/50
#  - 0s - loss: 26.5947
# Epoch 40/50
#  - 0s - loss: 21.7665
# Epoch 41/50
#  - 0s - loss: 23.7898
# Epoch 42/50
#  - 0s - loss: 25.1910
# Epoch 43/50
#  - 0s - loss: 23.1373
# Epoch 44/50
#  - 0s - loss: 22.2146
# Epoch 45/50
#  - 0s - loss: 22.7930
# Epoch 46/50
#  - 0s - loss: 23.2169
# Epoch 47/50
#  - 0s - loss: 23.9780
# Epoch 48/50
#  - 0s - loss: 25.4860
# Epoch 49/50
#  - 0s - loss: 22.1556
# Epoch 50/50
#  - 0s - loss: 24.0958
# Epoch 1/50
#  - 0s - loss: 25.7526
# Epoch 2/50
#  - 0s - loss: 22.8092
# Epoch 3/50
#  - 0s - loss: 22.2352
# Epoch 4/50
#  - 0s - loss: 26.5570
# Epoch 5/50
#  - 0s - loss: 23.1742
# Epoch 6/50
#  - 1s - loss: 25.7304
# Epoch 7/50
#  - 0s - loss: 23.2345
# Epoch 8/50
#  - 1s - loss: 22.6542
# Epoch 9/50
#  - 0s - loss: 23.0785
# Epoch 10/50
#  - 0s - loss: 25.2175
# Epoch 11/50
#  - 0s - loss: 23.3355
# Epoch 12/50
#  - 0s - loss: 21.9390
# Epoch 13/50
#  - 0s - loss: 27.0018
# Epoch 14/50
#  - 0s - loss: 27.5222
# Epoch 15/50
#  - 0s - loss: 23.1829
# Epoch 16/50
#  - 0s - loss: 32.5554
# Epoch 17/50
#  - 0s - loss: 26.8786
# Epoch 18/50
#  - 0s - loss: 24.1811
# Epoch 19/50
#  - 0s - loss: 22.5653
# Epoch 20/50
#  - 0s - loss: 24.2780
# Epoch 21/50
#  - 0s - loss: 23.5331
# Epoch 22/50
#  - 0s - loss: 22.8166
# Epoch 23/50
#  - 0s - loss: 23.3835
# Epoch 24/50
#  - 0s - loss: 21.5609
# Epoch 25/50
#  - 0s - loss: 24.4081
# Epoch 26/50
#  - 0s - loss: 23.2698
# Epoch 27/50
#  - 0s - loss: 25.1297
# Epoch 28/50
#  - 0s - loss: 23.6211
# Epoch 29/50
#  - 0s - loss: 23.3740
# Epoch 30/50
#  - 0s - loss: 24.1793
# Epoch 31/50
#  - 0s - loss: 24.7678
# Epoch 32/50
#  - 0s - loss: 30.8255
# Epoch 33/50
#  - 0s - loss: 23.8551
# Epoch 34/50
#  - 0s - loss: 23.6449
# Epoch 35/50
#  - 0s - loss: 25.4349
# Epoch 36/50
#  - 0s - loss: 25.7048
# Epoch 37/50
#  - 0s - loss: 25.9390
# Epoch 38/50
#  - 0s - loss: 23.6612
# Epoch 39/50
#  - 0s - loss: 27.3634
# Epoch 40/50
#  - 0s - loss: 26.4953
# Epoch 41/50
#  - 0s - loss: 26.9793
# Epoch 42/50
#  - 0s - loss: 24.7154
# Epoch 43/50
#  - 0s - loss: 26.0910
# Epoch 44/50
#  - 0s - loss: 23.0304
# Epoch 45/50
#  - 0s - loss: 23.6189
# Epoch 46/50
#  - 0s - loss: 26.5677
# Epoch 47/50
#  - 0s - loss: 25.5062
# Epoch 48/50
#  - 1s - loss: 23.6493
# Epoch 49/50
#  - 0s - loss: 29.9389
# Epoch 50/50
#  - 0s - loss: 24.5990
# Epoch 1/50
#  - 0s - loss: 25.1328
# Epoch 2/50
#  - 0s - loss: 22.1929
# Epoch 3/50
#  - 0s - loss: 20.8397
# Epoch 4/50
#  - 0s - loss: 23.3649
# Epoch 5/50
#  - 0s - loss: 27.9934
# Epoch 6/50
#  - 0s - loss: 24.8238
# Epoch 7/50
#  - 0s - loss: 32.0351
# Epoch 8/50
#  - 0s - loss: 23.3959
# Epoch 9/50
#  - 1s - loss: 22.1824
# Epoch 10/50
#  - 0s - loss: 23.4005
# Epoch 11/50
#  - 1s - loss: 26.1941
# Epoch 12/50
#  - 0s - loss: 23.3921
# Epoch 13/50
#  - 0s - loss: 23.1372
# Epoch 14/50
#  - 0s - loss: 23.8702
# Epoch 15/50
#  - 0s - loss: 22.1559
# Epoch 16/50
#  - 0s - loss: 23.5817
# Epoch 17/50
#  - 0s - loss: 22.6659
# Epoch 18/50
#  - 0s - loss: 22.2177
# Epoch 19/50
#  - 0s - loss: 26.8025
# Epoch 20/50
#  - 0s - loss: 26.2647
# Epoch 21/50
#  - 0s - loss: 25.5964
# Epoch 22/50
#  - 0s - loss: 22.5777
# Epoch 23/50
#  - 0s - loss: 22.6889
# Epoch 24/50
#  - 0s - loss: 21.1837
# Epoch 25/50
#  - 0s - loss: 23.2654
# Epoch 26/50
#  - 0s - loss: 21.4316
# Epoch 27/50
#  - 0s - loss: 21.6306
# Epoch 28/50
#  - 0s - loss: 20.1073
# Epoch 29/50
#  - 0s - loss: 26.3668
# Epoch 30/50
#  - 0s - loss: 23.6391
# Epoch 31/50
#  - 0s - loss: 25.0171
# Epoch 32/50
#  - 0s - loss: 20.7268
# Epoch 33/50
#  - 0s - loss: 25.4587
# Epoch 34/50
#  - 0s - loss: 26.2728
# Epoch 35/50
#  - 0s - loss: 23.7379
# Epoch 36/50
#  - 0s - loss: 26.6036
# Epoch 37/50
#  - 0s - loss: 24.7077
# Epoch 38/50
#  - 0s - loss: 22.0505
# Epoch 39/50
#  - 0s - loss: 22.7987
# Epoch 40/50
#  - 0s - loss: 26.1071
# Epoch 41/50
#  - 0s - loss: 22.4851
# Epoch 42/50
#  - 0s - loss: 22.1198
# Epoch 43/50
#  - 0s - loss: 23.3171
# Epoch 44/50
#  - 0s - loss: 25.6845
# Epoch 45/50
#  - 0s - loss: 21.3438
# Epoch 46/50
#  - 0s - loss: 21.4487
# Epoch 47/50
#  - 0s - loss: 23.2005
# Epoch 48/50
#  - 0s - loss: 21.5118
# Epoch 49/50
#  - 0s - loss: 22.9617
# Epoch 50/50
#  - 0s - loss: 23.8170
# Epoch 1/50
#  - 0s - loss: 27.5654
# Epoch 2/50
#  - 0s - loss: 25.8395
# Epoch 3/50
#  - 0s - loss: 23.6575
# Epoch 4/50
#  - 0s - loss: 22.9959
# Epoch 5/50
#  - 1s - loss: 22.8203
# Epoch 6/50
#  - 0s - loss: 20.5846
# Epoch 7/50
#  - 0s - loss: 30.4582
# Epoch 8/50
#  - 0s - loss: 21.8384
# Epoch 9/50
#  - 0s - loss: 20.6392
# Epoch 10/50
#  - 0s - loss: 23.0002
# Epoch 11/50
#  - 1s - loss: 23.0201
# Epoch 12/50
#  - 0s - loss: 20.8129
# Epoch 13/50
#  - 0s - loss: 21.1397
# Epoch 14/50
#  - 1s - loss: 25.6644
# Epoch 15/50
#  - 0s - loss: 24.0806
# Epoch 16/50
#  - 0s - loss: 24.9718
# Epoch 17/50
#  - 0s - loss: 30.8156
# Epoch 18/50
#  - 0s - loss: 24.6543
# Epoch 19/50
#  - 0s - loss: 22.8160
# Epoch 20/50
#  - 0s - loss: 22.6324
# Epoch 21/50
#  - 0s - loss: 25.5427
# Epoch 22/50
#  - 0s - loss: 23.6060
# Epoch 23/50
#  - 0s - loss: 24.8041
# Epoch 24/50
#  - 0s - loss: 23.3736
# Epoch 25/50
#  - 0s - loss: 25.5847
# Epoch 26/50
#  - 0s - loss: 25.2626
# Epoch 27/50
#  - 0s - loss: 24.2801
# Epoch 28/50
#  - 0s - loss: 26.5941
# Epoch 29/50
#  - 0s - loss: 25.7051
# Epoch 30/50
#  - 0s - loss: 24.7157
# Epoch 31/50
#  - 0s - loss: 26.1190
# Epoch 32/50
#  - 0s - loss: 23.5901
# Epoch 33/50
#  - 0s - loss: 21.4930
# Epoch 34/50
#  - 0s - loss: 21.3947
# Epoch 35/50
#  - 0s - loss: 24.6428
# Epoch 36/50
#  - 0s - loss: 21.3330
# Epoch 37/50
#  - 0s - loss: 23.8815
# Epoch 38/50
#  - 0s - loss: 38.7074
# Epoch 39/50
#  - 0s - loss: 42.7065
# Epoch 40/50
#  - 0s - loss: 35.3115
# Epoch 41/50
#  - 0s - loss: 21.5859
# Epoch 42/50
#  - 0s - loss: 21.6779
# Epoch 43/50
#  - 0s - loss: 20.8074
# Epoch 44/50
#  - 0s - loss: 22.0918
# Epoch 45/50
#  - 0s - loss: 22.9914
# Epoch 46/50
#  - 0s - loss: 21.9887
# Epoch 47/50
#  - 0s - loss: 22.1829
# Epoch 48/50
#  - 0s - loss: 24.1512
# Epoch 49/50
#  - 0s - loss: 21.2833
# Epoch 50/50
#  - 0s - loss: 25.9454
# Epoch 1/50
#  - 0s - loss: 21.8072
# Epoch 2/50
#  - 0s - loss: 20.4126
# Epoch 3/50
#  - 0s - loss: 26.6004
# Epoch 4/50
#  - 0s - loss: 36.8248
# Epoch 5/50
#  - 0s - loss: 24.3185
# Epoch 6/50
#  - 0s - loss: 21.5316
# Epoch 7/50
#  - 0s - loss: 21.0367
# Epoch 8/50
#  - 0s - loss: 22.2754
# Epoch 9/50
#  - 0s - loss: 20.6381
# Epoch 10/50
#  - 0s - loss: 21.1170
# Epoch 11/50
#  - 0s - loss: 24.9172
# Epoch 12/50
#  - 0s - loss: 22.6890
# Epoch 13/50
#  - 0s - loss: 21.6619
# Epoch 14/50
#  - 0s - loss: 21.5762
# Epoch 15/50
#  - 0s - loss: 22.0713
# Epoch 16/50
#  - 0s - loss: 21.8734
# Epoch 17/50
#  - 1s - loss: 21.7679
# Epoch 18/50
#  - 1s - loss: 22.9671
# Epoch 19/50
#  - 0s - loss: 20.5146
# Epoch 20/50
#  - 0s - loss: 21.3510
# Epoch 21/50
#  - 0s - loss: 24.9190
# Epoch 22/50
#  - 0s - loss: 20.0142
# Epoch 23/50
#  - 0s - loss: 25.0390
# Epoch 24/50
#  - 0s - loss: 21.1353
# Epoch 25/50
#  - 0s - loss: 24.6969
# Epoch 26/50
#  - 0s - loss: 22.8289
# Epoch 27/50
#  - 0s - loss: 25.8721
# Epoch 28/50
#  - 0s - loss: 22.5655
# Epoch 29/50
#  - 0s - loss: 21.3031
# Epoch 30/50
#  - 0s - loss: 21.4790
# Epoch 31/50
#  - 0s - loss: 20.9650
# Epoch 32/50
#  - 0s - loss: 20.5967
# Epoch 33/50
#  - 0s - loss: 23.6983
# Epoch 34/50
#  - 0s - loss: 21.8745
# Epoch 35/50
#  - 0s - loss: 21.8483
# Epoch 36/50
#  - 0s - loss: 24.7586
# Epoch 37/50
#  - 0s - loss: 25.4176
# Epoch 38/50
#  - 0s - loss: 22.8589
# Epoch 39/50
#  - 0s - loss: 22.7439
# Epoch 40/50
#  - 0s - loss: 23.4936
# Epoch 41/50
#  - 0s - loss: 25.7449
# Epoch 42/50
#  - 0s - loss: 29.2415
# Epoch 43/50
#  - 0s - loss: 24.8262
# Epoch 44/50
#  - 0s - loss: 21.7432
# Epoch 45/50
#  - 0s - loss: 20.1673
# Epoch 46/50
#  - 0s - loss: 23.0062
# Epoch 47/50
#  - 0s - loss: 27.4774
# Epoch 48/50
#  - 0s - loss: 21.9260
# Epoch 49/50
#  - 0s - loss: 21.2721
# Epoch 50/50
#  - 0s - loss: 24.3953
# Epoch 1/50
#  - 0s - loss: 21.6467
# Epoch 2/50
#  - 0s - loss: 21.7287
# Epoch 3/50
#  - 0s - loss: 20.9968
# Epoch 4/50
#  - 0s - loss: 21.6363
# Epoch 5/50
#  - 0s - loss: 21.5165
# Epoch 6/50
#  - 0s - loss: 21.0244
# Epoch 7/50
#  - 0s - loss: 21.1566
# Epoch 8/50
#  - 0s - loss: 22.5831
# Epoch 9/50
#  - 0s - loss: 20.3118
# Epoch 10/50
#  - 0s - loss: 23.7767
# Epoch 11/50
#  - 0s - loss: 27.0477
# Epoch 12/50
#  - 0s - loss: 23.7947
# Epoch 13/50
#  - 0s - loss: 20.3187
# Epoch 14/50
#  - 0s - loss: 21.3726
# Epoch 15/50
#  - 0s - loss: 20.4643
# Epoch 16/50
#  - 0s - loss: 20.6017
# Epoch 17/50
#  - 0s - loss: 25.6670
# Epoch 18/50
#  - 0s - loss: 23.0914
# Epoch 19/50
#  - 0s - loss: 27.3372
# Epoch 20/50
#  - 0s - loss: 23.1016
# Epoch 21/50
#  - 0s - loss: 21.3519
# Epoch 22/50
#  - 0s - loss: 24.5392
# Epoch 23/50
#  - 1s - loss: 24.3607
# Epoch 24/50
#  - 0s - loss: 21.4557
# Epoch 25/50
#  - 1s - loss: 22.9703
# Epoch 26/50
#  - 0s - loss: 22.4851
# Epoch 27/50
#  - 0s - loss: 20.8177
# Epoch 28/50
#  - 0s - loss: 22.2415
# Epoch 29/50
#  - 0s - loss: 22.5835
# Epoch 30/50
#  - 0s - loss: 20.6428
# Epoch 31/50
#  - 0s - loss: 21.4910
# Epoch 32/50
#  - 0s - loss: 21.3724
# Epoch 33/50
#  - 0s - loss: 20.4892
# Epoch 34/50
#  - 0s - loss: 31.4908
# Epoch 35/50
#  - 0s - loss: 30.2829
# Epoch 36/50
#  - 0s - loss: 24.7430
# Epoch 37/50
#  - 0s - loss: 21.6371
# Epoch 38/50
#  - 0s - loss: 21.5186
# Epoch 39/50
#  - 0s - loss: 21.9807
# Epoch 40/50
#  - 0s - loss: 22.2149
# Epoch 41/50
#  - 0s - loss: 22.9804
# Epoch 42/50
#  - 0s - loss: 22.2051
# Epoch 43/50
#  - 0s - loss: 21.2635
# Epoch 44/50
#  - 0s - loss: 21.1609
# Epoch 45/50
#  - 0s - loss: 20.6342
# Epoch 46/50
#  - 0s - loss: 25.9827
# Epoch 47/50
#  - 0s - loss: 23.1150
# Epoch 48/50
#  - 0s - loss: 19.2606
# Epoch 49/50
#  - 0s - loss: 20.8644
# Epoch 50/50
#  - 0s - loss: 21.7284
# Epoch 1/50
#  - 0s - loss: 21.0846
# Epoch 2/50
#  - 0s - loss: 24.5688
# Epoch 3/50
#  - 0s - loss: 20.4128
# Epoch 4/50
#  - 0s - loss: 21.0797
# Epoch 5/50
#  - 0s - loss: 21.9115
# Epoch 6/50
#  - 1s - loss: 24.4438
# Epoch 7/50
#  - 0s - loss: 24.3445
# Epoch 8/50
#  - 0s - loss: 24.2804
# Epoch 9/50
#  - 0s - loss: 31.2945
# Epoch 10/50
#  - 0s - loss: 22.8746
# Epoch 11/50
#  - 0s - loss: 20.8325
# Epoch 12/50
#  - 0s - loss: 20.5374
# Epoch 13/50
#  - 1s - loss: 22.1569
# Epoch 14/50
#  - 1s - loss: 21.7256
# Epoch 15/50
#  - 0s - loss: 20.2681
# Epoch 16/50
#  - 1s - loss: 20.6960
# Epoch 17/50
#  - 0s - loss: 19.4093
# Epoch 18/50
#  - 0s - loss: 21.8923
# Epoch 19/50
#  - 0s - loss: 23.6144
# Epoch 20/50
#  - 0s - loss: 22.3971
# Epoch 21/50
#  - 0s - loss: 20.5908
# Epoch 22/50
#  - 0s - loss: 22.2412
# Epoch 23/50
#  - 0s - loss: 20.9499
# Epoch 24/50
#  - 0s - loss: 21.8194
# Epoch 25/50
#  - 0s - loss: 22.8457
# Epoch 26/50
#  - 0s - loss: 28.1543
# Epoch 27/50
#  - 0s - loss: 27.5232
# Epoch 28/50
#  - 0s - loss: 21.8931
# Epoch 29/50
#  - 0s - loss: 22.1546
# Epoch 30/50
#  - 0s - loss: 19.2800
# Epoch 31/50
#  - 0s - loss: 20.8347
# Epoch 32/50
#  - 0s - loss: 21.5004
# Epoch 33/50
#  - 0s - loss: 23.5028
# Epoch 34/50
#  - 0s - loss: 20.3291
# Epoch 35/50
#  - 0s - loss: 19.8051
# Epoch 36/50
#  - 0s - loss: 22.4816
# Epoch 37/50
#  - 0s - loss: 23.0664
# Epoch 38/50
#  - 0s - loss: 21.0549
# Epoch 39/50
#  - 0s - loss: 20.5880
# Epoch 40/50
#  - 0s - loss: 21.7553
# Epoch 41/50
#  - 0s - loss: 22.3576
# Epoch 42/50
#  - 0s - loss: 23.4964
# Epoch 43/50
#  - 0s - loss: 22.3403
# Epoch 44/50
#  - 0s - loss: 21.8587
# Epoch 45/50
#  - 0s - loss: 21.9368
# Epoch 46/50
#  - 0s - loss: 20.4077
# Epoch 47/50
#  - 0s - loss: 19.6466
# Epoch 48/50
#  - 0s - loss: 19.9429
# Epoch 49/50
#  - 0s - loss: 24.6922
# Epoch 50/50
#  - 0s - loss: 28.8052
# Epoch 1/50
#  - 0s - loss: 21.5436
# Epoch 2/50
#  - 0s - loss: 22.3184
# Epoch 3/50
#  - 0s - loss: 21.5474
# Epoch 4/50
#  - 0s - loss: 22.0524
# Epoch 5/50
#  - 0s - loss: 21.5051
# Epoch 6/50
#  - 0s - loss: 21.1780
# Epoch 7/50
#  - 0s - loss: 20.1922
# Epoch 8/50
#  - 0s - loss: 19.8690
# Epoch 9/50
#  - 0s - loss: 21.5281
# Epoch 10/50
#  - 0s - loss: 18.9720
# Epoch 11/50
#  - 0s - loss: 19.8613
# Epoch 12/50
#  - 0s - loss: 20.3710
# Epoch 13/50
#  - 0s - loss: 20.5976
# Epoch 14/50
#  - 1s - loss: 21.8790
# Epoch 15/50
#  - 1s - loss: 21.1295
# Epoch 16/50
#  - 0s - loss: 23.5589
# Epoch 17/50
#  - 0s - loss: 22.5445
# Epoch 18/50
#  - 1s - loss: 22.6073
# Epoch 19/50
#  - 0s - loss: 23.0176
# Epoch 20/50
#  - 0s - loss: 23.3028
# Epoch 21/50
#  - 0s - loss: 21.5123
# Epoch 22/50
#  - 0s - loss: 22.5540
# Epoch 23/50
#  - 0s - loss: 21.6992
# Epoch 24/50
#  - 0s - loss: 20.3448
# Epoch 25/50
#  - 0s - loss: 19.3691
# Epoch 26/50
#  - 0s - loss: 20.9504
# Epoch 27/50
#  - 0s - loss: 23.1194
# Epoch 28/50
#  - 0s - loss: 21.7561
# Epoch 29/50
#  - 0s - loss: 20.1791
# Epoch 30/50
#  - 0s - loss: 21.7825
# Epoch 31/50
#  - 0s - loss: 23.4942
# Epoch 32/50
#  - 0s - loss: 24.1232
# Epoch 33/50
#  - 0s - loss: 28.5225
# Epoch 34/50
#  - 0s - loss: 21.5966
# Epoch 35/50
#  - 0s - loss: 20.4282
# Epoch 36/50
#  - 0s - loss: 21.3670
# Epoch 37/50
#  - 0s - loss: 19.9725
# Epoch 38/50
#  - 0s - loss: 20.7426
# Epoch 39/50
#  - 0s - loss: 20.1134
# Epoch 40/50
#  - 0s - loss: 19.7830
# Epoch 41/50
#  - 0s - loss: 25.1497
# Epoch 42/50
#  - 0s - loss: 22.4471
# Epoch 43/50
#  - 0s - loss: 23.5371
# Epoch 44/50
#  - 0s - loss: 19.0052
# Epoch 45/50
#  - 0s - loss: 19.9433
# Epoch 46/50
#  - 0s - loss: 22.2001
# Epoch 47/50
#  - 0s - loss: 20.3480
# Epoch 48/50
#  - 0s - loss: 18.9415
# Epoch 49/50
#  - 0s - loss: 20.4382
# Epoch 50/50
#  - 0s - loss: 21.5358
# Epoch 1/50
#  - 0s - loss: 26.8847
# Epoch 2/50
#  - 0s - loss: 23.1250
# Epoch 3/50
#  - 0s - loss: 19.0108
# Epoch 4/50
#  - 0s - loss: 21.8031
# Epoch 5/50
#  - 0s - loss: 20.1981
# Epoch 6/50
#  - 0s - loss: 19.1242
# Epoch 7/50
#  - 0s - loss: 20.3138
# Epoch 8/50
#  - 0s - loss: 21.4698
# Epoch 9/50
#  - 0s - loss: 20.1868
# Epoch 10/50
#  - 0s - loss: 19.8632
# Epoch 11/50
#  - 0s - loss: 20.0841
# Epoch 12/50
#  - 0s - loss: 18.7920
# Epoch 13/50
#  - 0s - loss: 18.3774
# Epoch 14/50
#  - 0s - loss: 20.0346
# Epoch 15/50
#  - 0s - loss: 23.2080
# Epoch 16/50
#  - 0s - loss: 22.0770
# Epoch 17/50
#  - 0s - loss: 20.5351
# Epoch 18/50
#  - 0s - loss: 19.5545
# Epoch 19/50
#  - 0s - loss: 18.7412
# Epoch 20/50
#  - 2s - loss: 20.7605
# Epoch 21/50
#  - 0s - loss: 24.7367
# Epoch 22/50
#  - 1s - loss: 24.0056
# Epoch 23/50
#  - 0s - loss: 34.6108
# Epoch 24/50
#  - 0s - loss: 37.1564
# Epoch 25/50
#  - 0s - loss: 25.8081
# Epoch 26/50
#  - 0s - loss: 24.3469
# Epoch 27/50
#  - 0s - loss: 21.3691
# Epoch 28/50
#  - 0s - loss: 21.5510
# Epoch 29/50
#  - 0s - loss: 20.0218
# Epoch 30/50
#  - 0s - loss: 18.1395
# Epoch 31/50
#  - 0s - loss: 20.8713
# Epoch 32/50
#  - 0s - loss: 20.7803
# Epoch 33/50
#  - 0s - loss: 19.2222
# Epoch 34/50
#  - 0s - loss: 18.4816
# Epoch 35/50
#  - 0s - loss: 28.9591
# Epoch 36/50
#  - 0s - loss: 20.0475
# Epoch 37/50
#  - 0s - loss: 19.0258
# Epoch 38/50
#  - 0s - loss: 20.0482
# Epoch 39/50
#  - 0s - loss: 19.9175
# Epoch 40/50
#  - 0s - loss: 20.3459
# Epoch 41/50
#  - 0s - loss: 19.7411
# Epoch 42/50
#  - 0s - loss: 20.2101
# Epoch 43/50
#  - 0s - loss: 18.8511
# Epoch 44/50
#  - 0s - loss: 20.2007
# Epoch 45/50
#  - 0s - loss: 18.5706
# Epoch 46/50
#  - 0s - loss: 19.5564
# Epoch 47/50
#  - 0s - loss: 18.8565
# Epoch 48/50
#  - 0s - loss: 22.5528
# Epoch 49/50
#  - 0s - loss: 20.0420
# Epoch 50/50
#  - 0s - loss: 19.6141
# Epoch 1/50
#  - 0s - loss: 19.1181
# Epoch 2/50
#  - 0s - loss: 19.3272
# Epoch 3/50
#  - 0s - loss: 19.7054
# Epoch 4/50
#  - 0s - loss: 19.0339
# Epoch 5/50
#  - 0s - loss: 20.1711
# Epoch 6/50
#  - 0s - loss: 19.3700
# Epoch 7/50
#  - 0s - loss: 23.6747
# Epoch 8/50
#  - 0s - loss: 19.6061
# Epoch 9/50
#  - 0s - loss: 19.6688
# Epoch 10/50
#  - 0s - loss: 18.6548
# Epoch 11/50
#  - 0s - loss: 18.7947
# Epoch 12/50
#  - 0s - loss: 20.3095
# Epoch 13/50
#  - 0s - loss: 21.1045
# Epoch 14/50
#  - 0s - loss: 21.7890
# Epoch 15/50
#  - 0s - loss: 23.3091
# Epoch 16/50
#  - 0s - loss: 21.5246
# Epoch 17/50
#  - 0s - loss: 19.0865
# Epoch 18/50
#  - 0s - loss: 25.7912
# Epoch 19/50
#  - 0s - loss: 21.0528
# Epoch 20/50
#  - 0s - loss: 28.0314
# Epoch 21/50
#  - 0s - loss: 21.7408
# Epoch 22/50
#  - 0s - loss: 24.8107
# Epoch 23/50
#  - 1s - loss: 20.8863
# Epoch 24/50
#  - 0s - loss: 19.7858
# Epoch 25/50
#  - 1s - loss: 19.2454
# Epoch 26/50
#  - 0s - loss: 20.6844
# Epoch 27/50
#  - 0s - loss: 20.4107
# Epoch 28/50
#  - 0s - loss: 19.5271
# Epoch 29/50
#  - 0s - loss: 18.0913
# Epoch 30/50
#  - 0s - loss: 19.2592
# Epoch 31/50
#  - 0s - loss: 19.0754
# Epoch 32/50
#  - 0s - loss: 19.0775
# Epoch 33/50
#  - 0s - loss: 25.1869
# Epoch 34/50
#  - 0s - loss: 23.4184
# Epoch 35/50
#  - 0s - loss: 22.9037
# Epoch 36/50
#  - 0s - loss: 19.2494
# Epoch 37/50
#  - 0s - loss: 19.4564
# Epoch 38/50
#  - 0s - loss: 20.8967
# Epoch 39/50
#  - 0s - loss: 18.9755
# Epoch 40/50
#  - 0s - loss: 20.4716
# Epoch 41/50
#  - 0s - loss: 19.8434
# Epoch 42/50
#  - 0s - loss: 20.4832
# Epoch 43/50
#  - 0s - loss: 21.2478
# Epoch 44/50
#  - 0s - loss: 22.7493
# Epoch 45/50
#  - 0s - loss: 22.5097
# Epoch 46/50
#  - 0s - loss: 19.8353
# Epoch 47/50
#  - 0s - loss: 20.5942
# Epoch 48/50
#  - 0s - loss: 18.4853
# Epoch 49/50
#  - 0s - loss: 19.6876
# Epoch 50/50
#  - 0s - loss: 18.4535
# Epoch 1/50
#  - 0s - loss: 21.3279
# Epoch 2/50
#  - 0s - loss: 22.7800
# Epoch 3/50
#  - 0s - loss: 19.6784
# Epoch 4/50
#  - 0s - loss: 19.2067
# Epoch 5/50
#  - 0s - loss: 19.2599
# Epoch 6/50
#  - 0s - loss: 17.9898
# Epoch 7/50
#  - 0s - loss: 23.2313
# Epoch 8/50
#  - 0s - loss: 20.7254
# Epoch 9/50
#  - 0s - loss: 19.8197
# Epoch 10/50
#  - 0s - loss: 18.9399
# Epoch 11/50
#  - 0s - loss: 18.4761
# Epoch 12/50
#  - 0s - loss: 18.4431
# Epoch 13/50
#  - 0s - loss: 22.5230
# Epoch 14/50
#  - 0s - loss: 25.8300
# Epoch 15/50
#  - 0s - loss: 22.3597
# Epoch 16/50
#  - 0s - loss: 19.2904
# Epoch 17/50
#  - 0s - loss: 18.2253
# Epoch 18/50
#  - 0s - loss: 23.1158
# Epoch 19/50
#  - 0s - loss: 19.6168
# Epoch 20/50
#  - 0s - loss: 18.5219
# Epoch 21/50
#  - 0s - loss: 20.7033
# Epoch 22/50
#  - 0s - loss: 20.2354
# Epoch 23/50
#  - 0s - loss: 19.2431
# Epoch 24/50
#  - 0s - loss: 19.8376
# Epoch 25/50
#  - 0s - loss: 19.0234
# Epoch 26/50
#  - 0s - loss: 26.0959
# Epoch 27/50
#  - 0s - loss: 29.7496
# Epoch 28/50
#  - 0s - loss: 23.9971
# Epoch 29/50
#  - 1s - loss: 19.4961
# Epoch 30/50
#  - 1s - loss: 18.5217
# Epoch 31/50
#  - 0s - loss: 20.3220
# Epoch 32/50
#  - 0s - loss: 18.0677
# Epoch 33/50
#  - 0s - loss: 19.7627
# Epoch 34/50
#  - 0s - loss: 17.5373
# Epoch 35/50
#  - 0s - loss: 18.5159
# Epoch 36/50
#  - 0s - loss: 18.4277
# Epoch 37/50
#  - 0s - loss: 17.8928
# Epoch 38/50
#  - 0s - loss: 17.9743
# Epoch 39/50
#  - 0s - loss: 19.5114
# Epoch 40/50
#  - 0s - loss: 18.1209
# Epoch 41/50
#  - 0s - loss: 20.3949
# Epoch 42/50
#  - 0s - loss: 17.7538
# Epoch 43/50
#  - 0s - loss: 18.5403
# Epoch 44/50
#  - 0s - loss: 21.5823
# Epoch 45/50
#  - 0s - loss: 19.7129
# Epoch 46/50
#  - 0s - loss: 19.5619
# Epoch 47/50
#  - 1s - loss: 20.5437
# Epoch 48/50
#  - 0s - loss: 19.5995
# Epoch 49/50
#  - 0s - loss: 18.0016
# Epoch 50/50
#  - 0s - loss: 21.1692
# Epoch 1/50
#  - 0s - loss: 20.9236
# Epoch 2/50
#  - 0s - loss: 17.6328
# Epoch 3/50
#  - 0s - loss: 19.4293
# Epoch 4/50
#  - 0s - loss: 19.4733
# Epoch 5/50
#  - 0s - loss: 19.4269
# Epoch 6/50
#  - 0s - loss: 18.2552
# Epoch 7/50
#  - 0s - loss: 19.7508
# Epoch 8/50
#  - 0s - loss: 20.4580
# Epoch 9/50
#  - 0s - loss: 17.4385
# Epoch 10/50
#  - 0s - loss: 20.1528
# Epoch 11/50
#  - 0s - loss: 18.5100
# Epoch 12/50
#  - 0s - loss: 19.1343
# Epoch 13/50
#  - 0s - loss: 19.5968
# Epoch 14/50
#  - 0s - loss: 19.5982
# Epoch 15/50
#  - 0s - loss: 22.7265
# Epoch 16/50
#  - 0s - loss: 19.5210
# Epoch 17/50
#  - 0s - loss: 19.5104
# Epoch 18/50
#  - 0s - loss: 21.3512
# Epoch 19/50
#  - 0s - loss: 21.1518
# Epoch 20/50
#  - 0s - loss: 22.6994
# Epoch 21/50
#  - 0s - loss: 18.0195
# Epoch 22/50
#  - 0s - loss: 21.0907
# Epoch 23/50
#  - 0s - loss: 18.4926
# Epoch 24/50
#  - 0s - loss: 17.8900
# Epoch 25/50
#  - 0s - loss: 17.0011
# Epoch 26/50
#  - 0s - loss: 18.4085
# Epoch 27/50
#  - 0s - loss: 19.4775
# Epoch 28/50
#  - 0s - loss: 21.1369
# Epoch 29/50
#  - 0s - loss: 18.5189
# Epoch 30/50
#  - 1s - loss: 19.4701
# Epoch 31/50
#  - 0s - loss: 18.4352
# Epoch 32/50
#  - 1s - loss: 18.0429
# Epoch 33/50
#  - 0s - loss: 21.2300
# Epoch 34/50
#  - 0s - loss: 18.6397
# Epoch 35/50
#  - 0s - loss: 22.8706
# Epoch 36/50
#  - 0s - loss: 18.8758
# Epoch 37/50
#  - 0s - loss: 17.5330
# Epoch 38/50
#  - 0s - loss: 18.4192
# Epoch 39/50
#  - 0s - loss: 20.3162
# Epoch 40/50
#  - 0s - loss: 20.4572
# Epoch 41/50
#  - 0s - loss: 20.1929
# Epoch 42/50
#  - 0s - loss: 17.7291
# Epoch 43/50
#  - 0s - loss: 18.1380
# Epoch 44/50
#  - 0s - loss: 17.8047
# Epoch 45/50
#  - 0s - loss: 18.7306
# Epoch 46/50
#  - 0s - loss: 17.6324
# Epoch 47/50
#  - 0s - loss: 17.4818
# Epoch 48/50
#  - 0s - loss: 20.1134
# Epoch 49/50
#  - 0s - loss: 21.4867
# Epoch 50/50
#  - 0s - loss: 25.5090
# Epoch 1/50
#  - 0s - loss: 18.5015
# Epoch 2/50
#  - 0s - loss: 22.4193
# Epoch 3/50
#  - 0s - loss: 18.9743
# Epoch 4/50
#  - 0s - loss: 17.7274
# Epoch 5/50
#  - 0s - loss: 18.1819
# Epoch 6/50
#  - 0s - loss: 18.9911
# Epoch 7/50
#  - 0s - loss: 18.5401
# Epoch 8/50
#  - 0s - loss: 18.6320
# Epoch 9/50
#  - 0s - loss: 21.1608
# Epoch 10/50
#  - 0s - loss: 22.0785
# Epoch 11/50
#  - 0s - loss: 20.4214
# Epoch 12/50
#  - 0s - loss: 17.3221
# Epoch 13/50
#  - 0s - loss: 24.5064
# Epoch 14/50
#  - 0s - loss: 19.6189
# Epoch 15/50
#  - 0s - loss: 19.7221
# Epoch 16/50
#  - 0s - loss: 17.8200
# Epoch 17/50
#  - 0s - loss: 20.2244
# Epoch 18/50
#  - 0s - loss: 18.8040
# Epoch 19/50
#  - 0s - loss: 18.2597
# Epoch 20/50
#  - 0s - loss: 17.2808
# Epoch 21/50
#  - 0s - loss: 18.5866
# Epoch 22/50
#  - 0s - loss: 17.1192
# Epoch 23/50
#  - 0s - loss: 18.6274
# Epoch 24/50
#  - 1s - loss: 17.9520
# Epoch 25/50
#  - 0s - loss: 17.2144
# Epoch 26/50
#  - 0s - loss: 17.4526
# Epoch 27/50
#  - 0s - loss: 17.8631
# Epoch 28/50
#  - 0s - loss: 18.6492
# Epoch 29/50
#  - 0s - loss: 18.7290
# Epoch 30/50
#  - 0s - loss: 17.4436
# Epoch 31/50
#  - 0s - loss: 16.5652
# Epoch 32/50
#  - 0s - loss: 17.0842
# Epoch 33/50
#  - 1s - loss: 17.9404
# Epoch 34/50
#  - 0s - loss: 16.6653
# Epoch 35/50
#  - 1s - loss: 18.7026
# Epoch 36/50
#  - 0s - loss: 17.6452
# Epoch 37/50
#  - 0s - loss: 17.4451
# Epoch 38/50
#  - 0s - loss: 18.7736
# Epoch 39/50
#  - 0s - loss: 20.0116
# Epoch 40/50
#  - 0s - loss: 21.0361
# Epoch 41/50
#  - 0s - loss: 18.7944
# Epoch 42/50
#  - 0s - loss: 18.7953
# Epoch 43/50
#  - 0s - loss: 17.4887
# Epoch 44/50
#  - 0s - loss: 17.8732
# Epoch 45/50
#  - 0s - loss: 22.2173
# Epoch 46/50
#  - 0s - loss: 19.7450
# Epoch 47/50
#  - 0s - loss: 18.1392
# Epoch 48/50
#  - 0s - loss: 18.3072
# Epoch 49/50
#  - 0s - loss: 18.8723
# Epoch 50/50
#  - 0s - loss: 19.9442
# Epoch 1/50
#  - 0s - loss: 18.7529
# Epoch 2/50
#  - 0s - loss: 16.7556
# Epoch 3/50
#  - 0s - loss: 16.8670
# Epoch 4/50
#  - 0s - loss: 17.8411
# Epoch 5/50
#  - 0s - loss: 18.7450
# Epoch 6/50
#  - 0s - loss: 17.6616
# Epoch 7/50
#  - 0s - loss: 18.1704
# Epoch 8/50
#  - 0s - loss: 18.1373
# Epoch 9/50
#  - 0s - loss: 17.0345
# Epoch 10/50
#  - 0s - loss: 16.5427
# Epoch 11/50
#  - 0s - loss: 17.4684
# Epoch 12/50
#  - 0s - loss: 18.0718
# Epoch 13/50
#  - 0s - loss: 20.7055
# Epoch 14/50
#  - 0s - loss: 20.1305
# Epoch 15/50
#  - 0s - loss: 18.3866
# Epoch 16/50
#  - 0s - loss: 16.8135
# Epoch 17/50
#  - 0s - loss: 18.4719
# Epoch 18/50
#  - 0s - loss: 18.0786
# Epoch 19/50
#  - 0s - loss: 16.3900
# Epoch 20/50
#  - 0s - loss: 17.0661
# Epoch 21/50
#  - 0s - loss: 17.5973
# Epoch 22/50
#  - 0s - loss: 17.4599
# Epoch 23/50
#  - 0s - loss: 19.1191
# Epoch 24/50
#  - 0s - loss: 17.4328
# Epoch 25/50
#  - 0s - loss: 19.2359
# Epoch 26/50
#  - 0s - loss: 17.2104
# Epoch 27/50
#  - 0s - loss: 20.5939
# Epoch 28/50
#  - 0s - loss: 19.9804
# Epoch 29/50
#  - 0s - loss: 20.0853
# Epoch 30/50
#  - 0s - loss: 19.0340
# Epoch 31/50
#  - 0s - loss: 17.5872
# Epoch 32/50
#  - 0s - loss: 17.0438
# Epoch 33/50
#  - 0s - loss: 17.4743
# Epoch 34/50
#  - 0s - loss: 19.2733
# Epoch 35/50
#  - 0s - loss: 21.6212
# Epoch 36/50
#  - 0s - loss: 19.6337
# Epoch 37/50
#  - 0s - loss: 18.7693
# Epoch 38/50
#  - 0s - loss: 23.1135
# Epoch 39/50
#  - 0s - loss: 22.3150
# Epoch 40/50
#  - 1s - loss: 17.9019
# Epoch 41/50
#  - 0s - loss: 17.4814
# Epoch 42/50
#  - 1s - loss: 19.2724
# Epoch 43/50
#  - 0s - loss: 19.0818
# Epoch 44/50
#  - 0s - loss: 20.8805
# Epoch 45/50
#  - 0s - loss: 20.1444
# Epoch 46/50
#  - 0s - loss: 18.7116
# Epoch 47/50
#  - 0s - loss: 17.8209
# Epoch 48/50
#  - 0s - loss: 18.1237
# Epoch 49/50
#  - 0s - loss: 17.6514
# Epoch 50/50
#  - 0s - loss: 19.0473
# Epoch 1/50
#  - 0s - loss: 16.5013
# Epoch 2/50
#  - 0s - loss: 16.5621
# Epoch 3/50
#  - 0s - loss: 18.0829
# Epoch 4/50
#  - 0s - loss: 16.2466
# Epoch 5/50
#  - 0s - loss: 16.3310
# Epoch 6/50
#  - 0s - loss: 16.3295
# Epoch 7/50
#  - 0s - loss: 16.4326
# Epoch 8/50
#  - 0s - loss: 15.9495
# Epoch 9/50
#  - 0s - loss: 16.8700
# Epoch 10/50
#  - 0s - loss: 21.9804
# Epoch 11/50
#  - 0s - loss: 20.1028
# Epoch 12/50
#  - 0s - loss: 17.4128
# Epoch 13/50
#  - 0s - loss: 17.7338
# Epoch 14/50
#  - 0s - loss: 17.9594
# Epoch 15/50
#  - 0s - loss: 18.8718
# Epoch 16/50
#  - 0s - loss: 18.2291
# Epoch 17/50
#  - 0s - loss: 19.9891
# Epoch 18/50
#  - 0s - loss: 19.9132
# Epoch 19/50
#  - 0s - loss: 19.0004
# Epoch 20/50
#  - 0s - loss: 17.9569
# Epoch 21/50
#  - 0s - loss: 17.5612
# Epoch 22/50
#  - 0s - loss: 17.0244
# Epoch 23/50
#  - 0s - loss: 17.5943
# Epoch 24/50
#  - 0s - loss: 17.2963
# Epoch 25/50
#  - 0s - loss: 18.4646
# Epoch 26/50
#  - 0s - loss: 18.0102
# Epoch 27/50
#  - 0s - loss: 20.0364
# Epoch 28/50
#  - 0s - loss: 16.0043
# Epoch 29/50
#  - 0s - loss: 16.2061
# Epoch 30/50
#  - 0s - loss: 16.1034
# Epoch 31/50
#  - 0s - loss: 16.6739
# Epoch 32/50
#  - 0s - loss: 17.0854
# Epoch 33/50
#  - 0s - loss: 17.9254
# Epoch 34/50
#  - 0s - loss: 18.1530
# Epoch 35/50
#  - 0s - loss: 18.7117
# Epoch 36/50
#  - 0s - loss: 17.4392
# Epoch 37/50
#  - 0s - loss: 16.9918
# Epoch 38/50
#  - 0s - loss: 16.5523
# Epoch 39/50
#  - 0s - loss: 18.6015
# Epoch 40/50
#  - 0s - loss: 16.5214
# Epoch 41/50
#  - 0s - loss: 16.3461
# Epoch 42/50
#  - 0s - loss: 16.4710
# Epoch 43/50
#  - 0s - loss: 16.1080
# Epoch 44/50
#  - 0s - loss: 17.4310
# Epoch 45/50
#  - 0s - loss: 16.9817
# Epoch 46/50
#  - 0s - loss: 18.5426
# Epoch 47/50
#  - 1s - loss: 17.3841
# Epoch 48/50
#  - 0s - loss: 16.9278
# Epoch 49/50
#  - 0s - loss: 18.1932
# Epoch 50/50
#  - 1s - loss: 17.5572
# Epoch 1/50
#  - 0s - loss: 16.3075
# Epoch 2/50
#  - 0s - loss: 16.2954
# Epoch 3/50
#  - 0s - loss: 17.0441
# Epoch 4/50
#  - 0s - loss: 15.3135
# Epoch 5/50
#  - 0s - loss: 15.6431
# Epoch 6/50
#  - 0s - loss: 15.8256
# Epoch 7/50
#  - 0s - loss: 16.5066
# Epoch 8/50
#  - 0s - loss: 15.7955
# Epoch 9/50
#  - 0s - loss: 16.7364
# Epoch 10/50
#  - 0s - loss: 17.5933
# Epoch 11/50
#  - 0s - loss: 17.5886
# Epoch 12/50
#  - 0s - loss: 17.6334
# Epoch 13/50
#  - 0s - loss: 17.4679
# Epoch 14/50
#  - 0s - loss: 17.4345
# Epoch 15/50
#  - 0s - loss: 17.1823
# Epoch 16/50
#  - 0s - loss: 18.6101
# Epoch 17/50
#  - 0s - loss: 16.8290
# Epoch 18/50
#  - 0s - loss: 16.5934
# Epoch 19/50
#  - 0s - loss: 15.5249
# Epoch 20/50
#  - 0s - loss: 21.9098
# Epoch 21/50
#  - 0s - loss: 23.3346
# Epoch 22/50
#  - 0s - loss: 17.8023
# Epoch 23/50
#  - 0s - loss: 19.1551
# Epoch 24/50
#  - 0s - loss: 18.5984
# Epoch 25/50
#  - 0s - loss: 17.3103
# Epoch 26/50
#  - 0s - loss: 17.3527
# Epoch 27/50
#  - 0s - loss: 16.1706
# Epoch 28/50
#  - 0s - loss: 16.2594
# Epoch 29/50
#  - 0s - loss: 19.4042
# Epoch 30/50
#  - 0s - loss: 17.6493
# Epoch 31/50
#  - 0s - loss: 15.9227
# Epoch 32/50
#  - 0s - loss: 15.6308
# Epoch 33/50
#  - 0s - loss: 16.1572
# Epoch 34/50
#  - 1s - loss: 15.7594
# Epoch 35/50
#  - 0s - loss: 15.7768
# Epoch 36/50
#  - 0s - loss: 15.6668
# Epoch 37/50
#  - 0s - loss: 17.9955
# Epoch 38/50
#  - 0s - loss: 18.3686
# Epoch 39/50
#  - 0s - loss: 15.9695
# Epoch 40/50
#  - 0s - loss: 15.9327
# Epoch 41/50
#  - 0s - loss: 15.8249
# Epoch 42/50
#  - 0s - loss: 17.4491
# Epoch 43/50
#  - 0s - loss: 16.0731
# Epoch 44/50
#  - 0s - loss: 15.0095
# Epoch 45/50
#  - 0s - loss: 17.4391
# Epoch 46/50
#  - 0s - loss: 17.4130
# Epoch 47/50
#  - 0s - loss: 17.2385
# Epoch 48/50
#  - 0s - loss: 15.6737
# Epoch 49/50
#  - 0s - loss: 15.5108
# Epoch 50/50
#  - 1s - loss: 16.3214
# Epoch 1/50
#  - 0s - loss: 15.7185
# Epoch 2/50
#  - 1s - loss: 15.7487
# Epoch 3/50
#  - 0s - loss: 16.4642
# Epoch 4/50
#  - 0s - loss: 17.9582
# Epoch 5/50
#  - 0s - loss: 21.7158
# Epoch 6/50
#  - 0s - loss: 18.1497
# Epoch 7/50
#  - 0s - loss: 16.7711
# Epoch 8/50
#  - 0s - loss: 19.2572
# Epoch 9/50
#  - 0s - loss: 15.8768
# Epoch 10/50
#  - 0s - loss: 17.5272
# Epoch 11/50
#  - 0s - loss: 15.9817
# Epoch 12/50
#  - 0s - loss: 15.6772
# Epoch 13/50
#  - 0s - loss: 19.2424
# Epoch 14/50
#  - 0s - loss: 17.3801
# Epoch 15/50
#  - 0s - loss: 16.3776
# Epoch 16/50
#  - 0s - loss: 15.8906
# Epoch 17/50
#  - 0s - loss: 15.8993
# Epoch 18/50
#  - 0s - loss: 18.4924
# Epoch 19/50
#  - 0s - loss: 16.5000
# Epoch 20/50
#  - 0s - loss: 14.8540
# Epoch 21/50
#  - 0s - loss: 15.6667
# Epoch 22/50
#  - 0s - loss: 15.7513
# Epoch 23/50
#  - 0s - loss: 14.7954
# Epoch 24/50
#  - 0s - loss: 14.8047
# Epoch 25/50
#  - 0s - loss: 16.7621
# Epoch 26/50
#  - 0s - loss: 16.4526
# Epoch 27/50
#  - 0s - loss: 16.4042
# Epoch 28/50
#  - 0s - loss: 17.6392
# Epoch 29/50
#  - 0s - loss: 16.0463
# Epoch 30/50
#  - 0s - loss: 15.9833
# Epoch 31/50
#  - 0s - loss: 15.5522
# Epoch 32/50
#  - 0s - loss: 16.1085
# Epoch 33/50
#  - 0s - loss: 15.4884
# Epoch 34/50
#  - 0s - loss: 15.7858
# Epoch 35/50
#  - 0s - loss: 17.5972
# Epoch 36/50
#  - 0s - loss: 18.7412
# Epoch 37/50
#  - 0s - loss: 19.0099
# Epoch 38/50
#  - 0s - loss: 15.2706
# Epoch 39/50
#  - 0s - loss: 16.4610
# Epoch 40/50
#  - 0s - loss: 15.5799
# Epoch 41/50
#  - 0s - loss: 15.4738
# Epoch 42/50
#  - 0s - loss: 15.0195
# Epoch 43/50
#  - 0s - loss: 15.5361
# Epoch 44/50
#  - 0s - loss: 15.5844
# Epoch 45/50
#  - 0s - loss: 15.9365
# Epoch 46/50
#  - 1s - loss: 15.0772
# Epoch 47/50
#  - 0s - loss: 14.8780
# Epoch 48/50
#  - 0s - loss: 14.9415
# Epoch 49/50
#  - 0s - loss: 16.1102
# Epoch 50/50
#  - 0s - loss: 17.5009
# Epoch 1/50
#  - 0s - loss: 14.4266
# Epoch 2/50
#  - 1s - loss: 15.3069
# Epoch 3/50
#  - 0s - loss: 15.1667
# Epoch 4/50
#  - 1s - loss: 16.1510
# Epoch 5/50
#  - 0s - loss: 16.3846
# Epoch 6/50
#  - 0s - loss: 15.7509
# Epoch 7/50
#  - 0s - loss: 15.1841
# Epoch 8/50
#  - 0s - loss: 14.9055
# Epoch 9/50
#  - 0s - loss: 15.0909
# Epoch 10/50
#  - 0s - loss: 14.5746
# Epoch 11/50
#  - 0s - loss: 13.4257
# Epoch 12/50
#  - 0s - loss: 15.2319
# Epoch 13/50
#  - 0s - loss: 15.7369
# Epoch 14/50
#  - 0s - loss: 15.0888
# Epoch 15/50
#  - 0s - loss: 15.9122
# Epoch 16/50
#  - 0s - loss: 17.3744
# Epoch 17/50
#  - 0s - loss: 15.1215
# Epoch 18/50
#  - 0s - loss: 15.8923
# Epoch 19/50
#  - 0s - loss: 14.2308
# ...
# Epoch 28/50
#  - 0s - loss: 11.3919
# Epoch 29/50
#  - 0s - loss: 12.0772
# Epoch 30/50
#  - 0s - loss: 12.0849
# Epoch 31/50
#  - 0s - loss: 14.3784
# Epoch 32/50
#  - 0s - loss: 11.0479
# Epoch 33/50
#  - 0s - loss: 12.4217
# Epoch 34/50
#  - 0s - loss: 11.9542
# Epoch 35/50
#  - 0s - loss: 12.5239
# Epoch 36/50
#  - 0s - loss: 11.6964
# Epoch 37/50
#  - 0s - loss: 11.8295
# Epoch 38/50
#  - 1s - loss: 11.9368
# Epoch 39/50
#  - 1s - loss: 12.3036
# Epoch 40/50
#  - 0s - loss: 12.1319
# Epoch 41/50
#  - 0s - loss: 11.2751
# Epoch 42/50
#  - 0s - loss: 12.3537
# Epoch 43/50
#  - 0s - loss: 12.7245
# Epoch 44/50
#  - 0s - loss: 14.1334
# Epoch 45/50
#  - 0s - loss: 13.2282
# Epoch 46/50
#  - 0s - loss: 14.4260
# Epoch 47/50
#  - 0s - loss: 16.9155
# Epoch 48/50
#  - 0s - loss: 13.7049
# Epoch 49/50
#  - 0s - loss: 11.0151
# Epoch 50/50
#  - 0s - loss: 11.1510
# Epoch 1/50
#  - 0s - loss: 12.8319
# Epoch 2/50
#  - 0s - loss: 13.9153
# Epoch 3/50
#  - 0s - loss: 15.4348
# Epoch 4/50
#  - 0s - loss: 16.5297
# Epoch 5/50
#  - 0s - loss: 11.8437
# Epoch 6/50
#  - 0s - loss: 12.5469
# Epoch 7/50
#  - 0s - loss: 12.4385
# Epoch 8/50
#  - 0s - loss: 11.8138
# Epoch 9/50
#  - 0s - loss: 12.5950
# Epoch 10/50
#  - 0s - loss: 11.1057
# Epoch 11/50
#  - 0s - loss: 11.8711
# Epoch 12/50
#  - 0s - loss: 12.3840
# Epoch 13/50
#  - 0s - loss: 11.1267
# Epoch 14/50
#  - 0s - loss: 11.3672
# Epoch 15/50
#  - 0s - loss: 12.3218
# Epoch 16/50
#  - 1s - loss: 11.7357
# Epoch 17/50
#  - 1s - loss: 12.2322
# Epoch 18/50
#  - 0s - loss: 11.3009
# Epoch 19/50
#  - 0s - loss: 11.2558
# Epoch 20/50
#  - 0s - loss: 12.3568
# Epoch 21/50
#  - 0s - loss: 13.0116
# Epoch 22/50
#  - 0s - loss: 11.6520
# Epoch 23/50
#  - 0s - loss: 11.7372
# Epoch 24/50
#  - 0s - loss: 12.4677
# Epoch 25/50
#  - 0s - loss: 11.2161
# Epoch 26/50
#  - 1s - loss: 11.4789
# Epoch 27/50
#  - 0s - loss: 12.9560
# Epoch 28/50
#  - 0s - loss: 10.8526
# Epoch 29/50
#  - 0s - loss: 11.1125
# Epoch 30/50
#  - 0s - loss: 11.5785
# Epoch 31/50
#  - 0s - loss: 12.2812
# Epoch 32/50
#  - 0s - loss: 12.4420
# Epoch 33/50
#  - 0s - loss: 13.2623
# Epoch 34/50
#  - 0s - loss: 11.8118
# Epoch 35/50
#  - 0s - loss: 11.0540
# Epoch 36/50
#  - 0s - loss: 11.3995
# Epoch 37/50
#  - 0s - loss: 13.2518
# Epoch 38/50
#  - 0s - loss: 11.8910
# Epoch 39/50
#  - 0s - loss: 11.5529
# Epoch 40/50
#  - 0s - loss: 11.3275
# Epoch 41/50
#  - 0s - loss: 11.3318
# Epoch 42/50
#  - 1s - loss: 12.0128
# Epoch 43/50
#  - 1s - loss: 11.6023
# Epoch 44/50
#  - 0s - loss: 11.9173
# Epoch 45/50
#  - 0s - loss: 11.7507
# Epoch 46/50
#  - 0s - loss: 11.2090
# Epoch 47/50
#  - 0s - loss: 11.4242
# Epoch 48/50
#  - 1s - loss: 10.9301
# Epoch 49/50
#  - 0s - loss: 10.9245
# Epoch 50/50
#  - 0s - loss: 11.3037
# Epoch 1/50
#  - 0s - loss: 12.9216
# Epoch 2/50
#  - 0s - loss: 11.6164
# Epoch 3/50
#  - 0s - loss: 13.6491
# Epoch 4/50
#  - 0s - loss: 18.1392
# Epoch 5/50
#  - 0s - loss: 12.2644
# Epoch 6/50
#  - 0s - loss: 11.2563
# Epoch 7/50
#  - 0s - loss: 12.3299
# Epoch 8/50
#  - 0s - loss: 10.9443
# Epoch 9/50
#  - 0s - loss: 11.7756
# Epoch 10/50
#  - 0s - loss: 11.3013
# Epoch 11/50
#  - 0s - loss: 11.2943
# Epoch 12/50
#  - 0s - loss: 12.1222
# Epoch 13/50
#  - 0s - loss: 11.0621
# Epoch 14/50
#  - 0s - loss: 12.0130
# Epoch 15/50
#  - 0s - loss: 11.7713
# Epoch 16/50
#  - 0s - loss: 10.8925
# Epoch 17/50
#  - 0s - loss: 10.9429
# Epoch 18/50
#  - 1s - loss: 11.9190
# Epoch 19/50
#  - 1s - loss: 12.6412
# Epoch 20/50
#  - 0s - loss: 10.9988
# Epoch 21/50
#  - 0s - loss: 11.7297
# Epoch 22/50
#  - 0s - loss: 11.6249
# Epoch 23/50
#  - 1s - loss: 10.9401
# Epoch 24/50
#  - 0s - loss: 11.7795
# Epoch 25/50
#  - 0s - loss: 11.9591
# Epoch 26/50
#  - 0s - loss: 11.7445
# Epoch 27/50
#  - 0s - loss: 14.8988
# Epoch 28/50
#  - 0s - loss: 14.8439
# Epoch 29/50
#  - 0s - loss: 14.2980
# Epoch 30/50
#  - 0s - loss: 12.3874
# Epoch 31/50
#  - 0s - loss: 12.0474
# Epoch 32/50
#  - 0s - loss: 12.5843
# Epoch 33/50
#  - 0s - loss: 10.9434
# Epoch 34/50
#  - 0s - loss: 10.8575
# Epoch 35/50
#  - 0s - loss: 12.6144
# Epoch 36/50
#  - 0s - loss: 12.5695
# Epoch 37/50
#  - 0s - loss: 11.9088
# Epoch 38/50
#  - 0s - loss: 10.7741
# Epoch 39/50
#  - 0s - loss: 10.6616
# Epoch 40/50
#  - 0s - loss: 10.8482
# Epoch 41/50
#  - 0s - loss: 11.4255
# Epoch 42/50
#  - 0s - loss: 11.5116
# Epoch 43/50
#  - 0s - loss: 11.0710
# Epoch 44/50
#  - 1s - loss: 13.1893
# Epoch 45/50
#  - 0s - loss: 13.2730
# Epoch 46/50
#  - 1s - loss: 12.5001
# Epoch 47/50
#  - 0s - loss: 10.7485
# Epoch 48/50
#  - 0s - loss: 12.1302
# Epoch 49/50
#  - 0s - loss: 12.1497
# Epoch 50/50
#  - 0s - loss: 12.8096
# Epoch 1/50
#  - 0s - loss: 11.4861
# Epoch 2/50
#  - 0s - loss: 11.0826
# Epoch 3/50
#  - 1s - loss: 11.4947
# Epoch 4/50
#  - 0s - loss: 10.6036
# Epoch 5/50
#  - 0s - loss: 11.4920
# Epoch 6/50
#  - 0s - loss: 17.3450
# Epoch 7/50
#  - 0s - loss: 12.9323
# Epoch 8/50
#  - 0s - loss: 12.1350
# Epoch 9/50
#  - 0s - loss: 13.4829
# Epoch 10/50
#  - 0s - loss: 11.7112
# Epoch 11/50
#  - 0s - loss: 12.3604
# Epoch 12/50
#  - 0s - loss: 11.5491
# Epoch 13/50
#  - 0s - loss: 11.6874
# Epoch 14/50
#  - 0s - loss: 11.8286
# Epoch 15/50
#  - 0s - loss: 12.4876
# Epoch 16/50
#  - 0s - loss: 11.1288
# Epoch 17/50
#  - 0s - loss: 10.5260
# Epoch 18/50
#  - 0s - loss: 10.4456
# Epoch 19/50
#  - 0s - loss: 10.8438
# Epoch 20/50
#  - 1s - loss: 11.1935
# Epoch 21/50
#  - 1s - loss: 11.9426
# Epoch 22/50
#  - 0s - loss: 11.7415
# Epoch 23/50
#  - 0s - loss: 10.6417
# Epoch 24/50
#  - 0s - loss: 11.5284
# Epoch 25/50
#  - 0s - loss: 10.7147
# Epoch 26/50
#  - 0s - loss: 12.5578
# Epoch 27/50
#  - 0s - loss: 14.1505
# Epoch 28/50
#  - 0s - loss: 10.8347
# Epoch 29/50
#  - 0s - loss: 15.3119
# Epoch 30/50
#  - 0s - loss: 10.9706
# Epoch 31/50
#  - 0s - loss: 11.9597
# Epoch 32/50
#  - 0s - loss: 11.8701
# Epoch 33/50
#  - 0s - loss: 13.1711
# Epoch 34/50
#  - 0s - loss: 12.2730
# Epoch 35/50
#  - 0s - loss: 14.5869
# Epoch 36/50
#  - 0s - loss: 12.3974
# Epoch 37/50
#  - 0s - loss: 11.2901
# Epoch 38/50
#  - 0s - loss: 12.0308
# Epoch 39/50
#  - 0s - loss: 10.7761
# Epoch 40/50
#  - 0s - loss: 12.7509
# Epoch 41/50
#  - 0s - loss: 11.3812
# Epoch 42/50
#  - 0s - loss: 12.7299
# Epoch 43/50
#  - 0s - loss: 14.1096
# Epoch 44/50
#  - 1s - loss: 12.2833
# Epoch 45/50
#  - 0s - loss: 12.7254
# Epoch 46/50
#  - 0s - loss: 12.4103
# Epoch 47/50
#  - 1s - loss: 10.9167
# Epoch 48/50
#  - 1s - loss: 10.4016
# Epoch 49/50
#  - 0s - loss: 10.4384
# Epoch 50/50
#  - 0s - loss: 11.1812
# Epoch 1/50
#  - 0s - loss: 11.5761
# Epoch 2/50
#  - 0s - loss: 11.9501
# Epoch 3/50
#  - 0s - loss: 11.5585
# Epoch 4/50
#  - 0s - loss: 12.5640
# Epoch 5/50
#  - 0s - loss: 11.4253
# Epoch 6/50
#  - 0s - loss: 12.3700
# Epoch 7/50
#  - 0s - loss: 13.0435
# Epoch 8/50
#  - 0s - loss: 10.5795
# Epoch 9/50
#  - 0s - loss: 11.4600
# Epoch 10/50
#  - 0s - loss: 11.8850
# Epoch 11/50
#  - 0s - loss: 12.7045
# Epoch 12/50
#  - 0s - loss: 12.2292
# Epoch 13/50
#  - 0s - loss: 13.4192
# Epoch 14/50
#  - 0s - loss: 13.2186
# Epoch 15/50
#  - 0s - loss: 12.1365
# Epoch 16/50
#  - 0s - loss: 10.6169
# Epoch 17/50
#  - 0s - loss: 10.8906
# Epoch 18/50
#  - 0s - loss: 10.2792
# Epoch 19/50
#  - 0s - loss: 12.5544
# Epoch 20/50
#  - 0s - loss: 13.1276
# Epoch 21/50
#  - 0s - loss: 10.7063
# Epoch 22/50
#  - 0s - loss: 10.7815
# Epoch 23/50
#  - 0s - loss: 10.8098
# Epoch 24/50
#  - 0s - loss: 12.2405
# Epoch 25/50
#  - 3s - loss: 10.9903
# Epoch 26/50
#  - 0s - loss: 10.5427
# Epoch 27/50
#  - 0s - loss: 10.7502
# Epoch 28/50
#  - 0s - loss: 11.7504
# Epoch 29/50
#  - 0s - loss: 14.1110
# Epoch 30/50
#  - 0s - loss: 13.1968
# Epoch 31/50
#  - 0s - loss: 12.7383
# Epoch 32/50
#  - 0s - loss: 13.1352
# Epoch 33/50
#  - 0s - loss: 11.9769
# Epoch 34/50
#  - 0s - loss: 12.6920
# Epoch 35/50
#  - 0s - loss: 12.5437
# Epoch 36/50
#  - 0s - loss: 11.7612
# Epoch 37/50
#  - 0s - loss: 11.2362
# Epoch 38/50
#  - 0s - loss: 10.4534
# Epoch 39/50
#  - 0s - loss: 13.9114
# Epoch 40/50
#  - 0s - loss: 12.4479
# Epoch 41/50
#  - 0s - loss: 12.5065
# Epoch 42/50
#  - 0s - loss: 11.1087
# Epoch 43/50
#  - 0s - loss: 10.8918
# Epoch 44/50
#  - 0s - loss: 10.5204
# Epoch 45/50
#  - 0s - loss: 11.0590
# Epoch 46/50
#  - 0s - loss: 11.2259
# Epoch 47/50
#  - 0s - loss: 11.0306
# Epoch 48/50
#  - 0s - loss: 11.8018
# Epoch 49/50
#  - 0s - loss: 10.5892
# Epoch 50/50
#  - 0s - loss: 11.2523
# Epoch 1/50
#  - 0s - loss: 10.8315
# Epoch 2/50
#  - 1s - loss: 11.2576
# Epoch 3/50
#  - 0s - loss: 13.3466
# Epoch 4/50
#  - 2s - loss: 11.6359
# Epoch 5/50
#  - 0s - loss: 10.5447
# Epoch 6/50
#  - 0s - loss: 11.3664
# Epoch 7/50
#  - 0s - loss: 10.3853
# Epoch 8/50
#  - 0s - loss: 10.7232
# Epoch 9/50
#  - 0s - loss: 11.3883
# Epoch 10/50
#  - 0s - loss: 10.7352
# Epoch 11/50
#  - 0s - loss: 10.2816
# Epoch 12/50
#  - 0s - loss: 12.0541
# Epoch 13/50
#  - 0s - loss: 11.6354
# Epoch 14/50
#  - 0s - loss: 12.8581
# Epoch 15/50
#  - 0s - loss: 11.4017
# Epoch 16/50
#  - 0s - loss: 11.3289
# Epoch 17/50
#  - 0s - loss: 12.0193
# Epoch 18/50
#  - 0s - loss: 12.1256
# Epoch 19/50
#  - 0s - loss: 11.5356
# Epoch 20/50
#  - 0s - loss: 12.1750
# Epoch 21/50
#  - 0s - loss: 10.7905
# Epoch 22/50
#  - 0s - loss: 11.2612
# Epoch 23/50
#  - 0s - loss: 10.4117
# Epoch 24/50
#  - 0s - loss: 10.7808
# Epoch 25/50
#  - 0s - loss: 11.7333
# Epoch 26/50
#  - 0s - loss: 10.9340
# Epoch 27/50
#  - 0s - loss: 11.6197
# Epoch 28/50
#  - 0s - loss: 10.3568
# Epoch 29/50
#  - 0s - loss: 10.3296
# Epoch 30/50
#  - 2s - loss: 10.6352
# Epoch 31/50
#  - 0s - loss: 11.1141
# Epoch 32/50
#  - 1s - loss: 11.5290
# Epoch 33/50
#  - 0s - loss: 10.2141
# Epoch 34/50
#  - 0s - loss: 11.5675
# Epoch 35/50
#  - 0s - loss: 12.7521
# Epoch 36/50
#  - 0s - loss: 11.1232
# Epoch 37/50
#  - 0s - loss: 10.4910
# Epoch 38/50
#  - 0s - loss: 11.2483
# Epoch 39/50
#  - 0s - loss: 11.3843
# Epoch 40/50
#  - 0s - loss: 11.9566
# Epoch 41/50
#  - 0s - loss: 10.3911
# Epoch 42/50
#  - 0s - loss: 11.8976
# Epoch 43/50
#  - 0s - loss: 11.7524
# Epoch 44/50
#  - 0s - loss: 10.7247
# Epoch 45/50
#  - 0s - loss: 11.0678
# Epoch 46/50
#  - 0s - loss: 10.6412
# Epoch 47/50
#  - 0s - loss: 10.2749
# Epoch 48/50
#  - 0s - loss: 13.2647
# Epoch 49/50
#  - 0s - loss: 10.6565
# Epoch 50/50
#  - 0s - loss: 10.5095
# Epoch 1/50
#  - 0s - loss: 11.0041
# Epoch 2/50
#  - 0s - loss: 11.2379
# Epoch 3/50
#  - 0s - loss: 11.9590
# Epoch 4/50
#  - 1s - loss: 10.7852
# Epoch 5/50
#  - 1s - loss: 10.8124
# Epoch 6/50
#  - 0s - loss: 14.0240
# Epoch 7/50
#  - 0s - loss: 12.6026
# Epoch 8/50
#  - 0s - loss: 11.9987
# Epoch 9/50
#  - 0s - loss: 11.0578
# Epoch 10/50
#  - 0s - loss: 10.9207
# Epoch 11/50
#  - 0s - loss: 10.8209
# Epoch 12/50
#  - 0s - loss: 11.3006
# Epoch 13/50
#  - 0s - loss: 11.1311
# Epoch 14/50
#  - 0s - loss: 11.0495
# Epoch 15/50
#  - 0s - loss: 11.3143
# Epoch 16/50
#  - 0s - loss: 11.5818
# Epoch 17/50
#  - 0s - loss: 10.1439
# Epoch 18/50
#  - 0s - loss: 10.2731
# Epoch 19/50
#  - 0s - loss: 9.7112
# Epoch 20/50
#  - 0s - loss: 10.8791
# Epoch 21/50
#  - 1s - loss: 10.6429
# Epoch 22/50
#  - 0s - loss: 10.7608
# Epoch 23/50
#  - 0s - loss: 11.1189
# Epoch 24/50
#  - 0s - loss: 11.5884
# Epoch 25/50
#  - 0s - loss: 10.1380
# Epoch 26/50
#  - 0s - loss: 10.7973
# Epoch 27/50
#  - 0s - loss: 10.1003
# Epoch 28/50
#  - 0s - loss: 11.6774
# Epoch 29/50
#  - 0s - loss: 10.9219
# Epoch 30/50
#  - 1s - loss: 10.6436
# Epoch 31/50
#  - 0s - loss: 10.9576
# Epoch 32/50
#  - 1s - loss: 12.0763
# Epoch 33/50
#  - 0s - loss: 12.2823
# Epoch 34/50
#  - 0s - loss: 11.2307
# Epoch 35/50
#  - 0s - loss: 12.9545
# Epoch 36/50
#  - 0s - loss: 13.1831
# Epoch 37/50
#  - 0s - loss: 11.3840
# Epoch 38/50
#  - 0s - loss: 11.2485
# Epoch 39/50
#  - 0s - loss: 10.0987
# Epoch 40/50
#  - 0s - loss: 10.6498
# Epoch 41/50
#  - 0s - loss: 10.6933
# Epoch 42/50
#  - 0s - loss: 10.7075
# Epoch 43/50
#  - 1s - loss: 10.5793
# Epoch 44/50
#  - 0s - loss: 13.9728
# Epoch 45/50
#  - 0s - loss: 15.8729
# Epoch 46/50
#  - 0s - loss: 11.5784
# Epoch 47/50
#  - 0s - loss: 10.9633
# Epoch 48/50
#  - 0s - loss: 11.2758
# Epoch 49/50
#  - 0s - loss: 11.3613
# Epoch 50/50
#  - 0s - loss: 11.4393
# Epoch 1/50
#  - 0s - loss: 14.3723
# Epoch 2/50
#  - 0s - loss: 10.7453
# Epoch 3/50
#  - 0s - loss: 9.9513
# Epoch 4/50
#  - 0s - loss: 10.4055
# Epoch 5/50
#  - 0s - loss: 10.2472
# Epoch 6/50
#  - 0s - loss: 9.7468
# Epoch 7/50
#  - 1s - loss: 11.7560
# Epoch 8/50
#  - 1s - loss: 10.2128
# Epoch 9/50
#  - 0s - loss: 10.5640
# Epoch 10/50
#  - 0s - loss: 10.5981
# Epoch 11/50
#  - 0s - loss: 11.6748
# Epoch 12/50
#  - 0s - loss: 10.9802
# Epoch 13/50
#  - 0s - loss: 11.2584
# Epoch 14/50
#  - 0s - loss: 11.8325
# Epoch 15/50
#  - 0s - loss: 10.6139
# Epoch 16/50
#  - 0s - loss: 11.6829
# Epoch 17/50
#  - 0s - loss: 11.6472
# Epoch 18/50
#  - 0s - loss: 12.9331
# Epoch 19/50
#  - 0s - loss: 12.2787
# Epoch 20/50
#  - 0s - loss: 11.6831
# Epoch 21/50
#  - 0s - loss: 12.4350
# Epoch 22/50
#  - 0s - loss: 11.6580
# Epoch 23/50
#  - 0s - loss: 10.8744
# Epoch 24/50
#  - 0s - loss: 16.0823
# Epoch 25/50
#  - 0s - loss: 12.8662
# Epoch 26/50
#  - 0s - loss: 12.7091
# Epoch 27/50
#  - 0s - loss: 10.4368
# Epoch 28/50
#  - 0s - loss: 9.9452
# Epoch 29/50
#  - 0s - loss: 10.5767
# Epoch 30/50
#  - 0s - loss: 10.6790
# Epoch 31/50
#  - 0s - loss: 10.7611
# Epoch 32/50
#  - 0s - loss: 11.0993
# Epoch 33/50
#  - 0s - loss: 11.1597
# Epoch 34/50
#  - 0s - loss: 9.8544
# Epoch 35/50
#  - 1s - loss: 11.8281
# Epoch 36/50
#  - 0s - loss: 10.7916
# Epoch 37/50
#  - 1s - loss: 10.6870
# Epoch 38/50
#  - 0s - loss: 10.0036
# Epoch 39/50
#  - 0s - loss: 10.5009
# Epoch 40/50
#  - 0s - loss: 11.8894
# Epoch 41/50
#  - 0s - loss: 11.4206
# Epoch 42/50
#  - 0s - loss: 12.8693
# Epoch 43/50
#  - 0s - loss: 12.6347
# Epoch 44/50
#  - 0s - loss: 10.7191
# Epoch 45/50
#  - 0s - loss: 10.1840
# Epoch 46/50
#  - 0s - loss: 11.3627
# Epoch 47/50
#  - 0s - loss: 10.6442
# Epoch 48/50
#  - 0s - loss: 10.6313
# Epoch 49/50
#  - 0s - loss: 10.7547
# Epoch 50/50
#  - 0s - loss: 11.7498
# Epoch 1/50
#  - 0s - loss: 10.7906
# Epoch 2/50
#  - 0s - loss: 10.7562
# Epoch 3/50
#  - 0s - loss: 11.5462
# Epoch 4/50
#  - 0s - loss: 10.8704
# Epoch 5/50
#  - 0s - loss: 10.4702
# Epoch 6/50
#  - 0s - loss: 10.9039
# Epoch 7/50
#  - 0s - loss: 11.2791
# Epoch 8/50
#  - 0s - loss: 11.1807
# Epoch 9/50
#  - 0s - loss: 10.5987
# Epoch 10/50
#  - 0s - loss: 11.2594
# Epoch 11/50
#  - 0s - loss: 12.1566
# Epoch 12/50
#  - 0s - loss: 11.4861
# Epoch 13/50
#  - 0s - loss: 11.9736
# Epoch 14/50
#  - 3s - loss: 11.0694
# Epoch 15/50
#  - 0s - loss: 11.0835
# Epoch 16/50
#  - 0s - loss: 10.6243
# Epoch 17/50
#  - 0s - loss: 10.0704
# Epoch 18/50
#  - 0s - loss: 11.1094
# Epoch 19/50
#  - 0s - loss: 11.0842
# Epoch 20/50
#  - 0s - loss: 10.8668
# Epoch 21/50
#  - 0s - loss: 12.3643
# Epoch 22/50
#  - 0s - loss: 12.6641
# Epoch 23/50
#  - 0s - loss: 12.9065
# Epoch 24/50
#  - 0s - loss: 11.5220
# Epoch 25/50
#  - 0s - loss: 10.3529
# Epoch 26/50
#  - 0s - loss: 11.0455
# Epoch 27/50
#  - 0s - loss: 11.3527
# Epoch 28/50
#  - 0s - loss: 11.0679
# Epoch 29/50
#  - 0s - loss: 11.2583
# Epoch 30/50
#  - 0s - loss: 11.2443
# Epoch 31/50
#  - 0s - loss: 10.4984
# Epoch 32/50
#  - 0s - loss: 10.4264
# Epoch 33/50
#  - 0s - loss: 10.7541
# Epoch 34/50
#  - 0s - loss: 11.0393
# Epoch 35/50
#  - 0s - loss: 10.9439
# Epoch 36/50
#  - 0s - loss: 9.7136
# Epoch 37/50
#  - 0s - loss: 9.9458
# Epoch 38/50
#  - 0s - loss: 10.5243
# Epoch 39/50
#  - 1s - loss: 10.0990
# Epoch 40/50
#  - 2s - loss: 9.8134
# Epoch 41/50
#  - 0s - loss: 9.5034
# Epoch 42/50
#  - 0s - loss: 11.2057
# Epoch 43/50
#  - 0s - loss: 10.9116
# Epoch 44/50
#  - 0s - loss: 10.8105
# Epoch 45/50
#  - 0s - loss: 10.3407
# Epoch 46/50
#  - 0s - loss: 10.3235
# Epoch 47/50
#  - 0s - loss: 12.6418
# Epoch 48/50
#  - 0s - loss: 12.1405
# Epoch 49/50
#  - 0s - loss: 10.6786
# Epoch 50/50
#  - 0s - loss: 14.0251
# Epoch 1/50
#  - 0s - loss: 15.5342
# Epoch 2/50
#  - 0s - loss: 10.7072
# Epoch 3/50
#  - 0s - loss: 10.2616
# Epoch 4/50
#  - 0s - loss: 9.4204
# Epoch 5/50
#  - 0s - loss: 10.0946
# Epoch 6/50
#  - 0s - loss: 10.2300
# Epoch 7/50
#  - 0s - loss: 9.9273
# Epoch 8/50
#  - 0s - loss: 11.0385
# Epoch 9/50
#  - 0s - loss: 10.7978
# Epoch 10/50
#  - 0s - loss: 12.9450
# Epoch 11/50
#  - 0s - loss: 11.9030
# Epoch 12/50
#  - 0s - loss: 12.2553
# Epoch 13/50
#  - 0s - loss: 10.7340
# Epoch 14/50
#  - 0s - loss: 9.8996
# Epoch 15/50
#  - 0s - loss: 11.7712
# Epoch 16/50
#  - 0s - loss: 16.2577
# Epoch 17/50
#  - 1s - loss: 9.9707
# Epoch 18/50
#  - 1s - loss: 10.1691
# Epoch 19/50
#  - 0s - loss: 11.2727
# Epoch 20/50
#  - 0s - loss: 10.0219
# Epoch 21/50
#  - 0s - loss: 12.7210
# Epoch 22/50
#  - 0s - loss: 11.4804
# Epoch 23/50
#  - 0s - loss: 10.9634
# Epoch 24/50
#  - 0s - loss: 10.5082
# Epoch 25/50
#  - 0s - loss: 11.2599
# Epoch 26/50
#  - 0s - loss: 10.2025
# Epoch 27/50
#  - 0s - loss: 11.3876
# Epoch 28/50
#  - 0s - loss: 10.9391
# Epoch 29/50
#  - 0s - loss: 10.4871
# Epoch 30/50
#  - 0s - loss: 9.9229
# Epoch 31/50
#  - 0s - loss: 10.2403
# Epoch 32/50
#  - 1s - loss: 10.6964
# Epoch 33/50
#  - 0s - loss: 9.9667
# Epoch 34/50
#  - 0s - loss: 9.8461
# Epoch 35/50
#  - 0s - loss: 10.1002
# Epoch 36/50
#  - 0s - loss: 9.6274
# Epoch 37/50
#  - 0s - loss: 9.2568
# Epoch 38/50
#  - 0s - loss: 10.5483
# Epoch 39/50
#  - 0s - loss: 10.8551
# Epoch 40/50
#  - 0s - loss: 12.1450
# Epoch 41/50
#  - 0s - loss: 11.1793
# Epoch 42/50
#  - 0s - loss: 11.2056
# Epoch 43/50
#  - 1s - loss: 11.1843
# Epoch 44/50
#  - 1s - loss: 13.2809
# Epoch 45/50
#  - 0s - loss: 11.3285
# Epoch 46/50
#  - 0s - loss: 10.3361
# Epoch 47/50
#  - 0s - loss: 10.8711
# Epoch 48/50
#  - 0s - loss: 11.1779
# Epoch 49/50
#  - 0s - loss: 10.7631
# Epoch 50/50
#  - 0s - loss: 15.7420
# 50

# %%
print(mean_error)
# Out:
# [80.76460034921692, 54.58992153857749, 57.28464650060962, 43.916111317249175, 42.11306837674192, 41.260765875674046, 38.21638091242246, 45.89372501348764, 38.42195720301657, 39.72361377203045, 53.80590213462634, 40.745121450791885, 42.06610512459059, 68.92117376056218, 37.036650173573534, 39.4913955749546, 45.094293303905346, 39.36356721379015, 44.44370464525981, 37.09856974081169, 36.89723281421615, 36.99758947487111, 38.547818271190245, 37.28988007253092, 35.2994297020635, 34.89870036268438, 33.8572181672102, 35.59531082310729, 33.42869578486565, 32.96898332054166, 35.081231659830934, 34.000786217221076, 32.80253311826156, 37.68165864086874, 44.191158321992674, 32.64142186447975, 35.734430487934084, 34.09558804617475, 40.744697789780034, 38.129675502994566, 32.77378113318756, 35.05810123598353, 33.45745801651893, 34.26635409539188, 32.79302763056416, 31.7646966368889, 44.30739410017524, 33.53531598314209, 40.140442796678116, 38.1270249279812]

# %%
from statistics import stdev 
print(stdev(mean_error))
# Out:
# 9.18927917206439

# %%
sum = 0
for i in mean_error:
    sum = sum + mean_error
